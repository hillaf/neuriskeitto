# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from model import EncoderRNN, AttnDecoderRNN
import json
import helpers


encoder_dict = torch.load('./model_v4.pt', map_location=torch.device('cpu'))['encoder_state_dict']
decoder_dict = torch.load('./model_v4.pt', map_location=torch.device('cpu'))['decoder_state_dict']
    
with open('../project_data/project_train_data_instr.json') as json_file:
    train_data = json.load(json_file)

# %%
N_EPOCHS = 15
LEARNING_RATE = 0.01
REPORT_EVERY = 1000
HIDDEN_DIM = 256
#BATCH_SIZE = 20
#N_LAYERS = 1
teacher_forcing_ratio = 1
TRAIN_SET_SIZE = 1000
n_words = 43863
MAX_LENGTH = 70

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_num_threads(10)

encoder = EncoderRNN(n_words, HIDDEN_DIM).to(device)
decoder = AttnDecoderRNN(HIDDEN_DIM, n_words, max_length=MAX_LENGTH).to(device)

encoder.load_state_dict(encoder_dict)
decoder.load_state_dict(decoder_dict)
# Out:
# <All keys matched successfully>

# %%
encoder.eval()
decoder.eval()

recipe_step_pairs, idx2word, word2idx, ml = helpers.get_tensor_data()
n_words = len(word2idx)
print(recipe_step_pairs[0])
# Out:
# Number of short ingredient lists:  130567
# Average ingredient list length: 14.175872007959267
# No ingredients filtered
# Max instruction step length:  70
# Number of long instructions:  61032
# Average instruction length: 149.95270527301457
# Total instruction steps:  489828
# Recipes filtered:  61455
# Recipes left after filtering:  75241
# Recipe step pairs:  223824
# <SOS> Preheat oven to 400 degrees F ( 205 degrees C ) . Butter a 9x9x2 inch baking pan . <EOS>
# <SOS> Melt 1 tablespoon butter in medium nonstick skillet over medium-low heat . Add onion and saute until tender , about 10 minutes . Cool . <EOS>
# (tensor([[43860],
#         [   17],
#         [   18],
#         [   19],
#         [   20],
#         [   21],
#         [   22],
#         [   23],
#         [   24],
#         [   21],
#         [   25],
#         [   26],
#         [   27],
#         [   28],
#         [   29],
#         [   30],
#         [   31],
#         [   32],
#         [   33],
#         [   27],
#         [43862]]), tensor([[43860],
#         [   34],
#         [   35],
#         [   36],
#         [    1],
#         [   37],
#         [   38],
#         [   39],
#         [   40],
#         [   41],
#         [   42],
#         [   43],
#         [   27],
#         [   44],
#         [    2],
#         [   45],
#         [   46],
#         [   47],
#         [   48],
#         [   49],
#         [   50],
#         [   51],
#         [   52],
#         [   27],
#         [   53],
#         [   27],
#         [43862]]))

# %%
from random import choice
from helpers import idx_to_words
from nltk.tokenize import sent_tokenize, word_tokenize
import re

def evaluate(encoder, decoder, input_tensor, gold_standard):
    with torch.no_grad():
        max_length = MAX_LENGTH
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden(device)

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        loss = 0
        
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[word2idx['<SOS>']]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if di < len(gold_standard):
                loss += loss_function(decoder_output, gold_standard[di])
            else:
                loss += loss_function(decoder_output, gold_standard[-1])
            if topi.item() == word2idx['<EOS>']:
                if di < len(gold_standard) and gold_standard[di] !=  word2idx['<EOS>']:
                    for dj in range(di, len(gold_standard)):
                        loss += loss_function(decoder_output, gold_standard[dj])
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(idx2word[str(topi.item())])

            decoder_input = topi.squeeze().detach()

        return decoded_words, loss.item()/len(gold_standard), decoder_attentions

    
def random_evaluate(evaluation_data, n=10):
    for i in range(n):
        pair = choice(evaluation_data)
        print('Instruction step', idx_to_words(pair[0], idx2word))
        print('Next step', idx_to_words(pair[1], idx2word))
        output_words, loss, attentions = evaluate(encoder, decoder, pair[0].to(device), pair[1].to(device))
        output_sentence = ' '.join(output_words)
        print('Generated instructions', output_sentence)
        print("Loss: ", loss)
        print('')
        
        
def evaluate_with_given_input(instruction_pair):
    output_words, loss, attentions = evaluate(encoder, decoder, instruction_pair[0].to(device), instruction_pair[1].to(device))
    output_sentence = ' '.join(output_words)
    return output_sentence, loss, attentions

    
def tokenize(instruction_step):
    words_tokenized = word_tokenize(instruction_step)
    return words_tokenized


def add_helper_tokens(step_tokenized):
    new_step = ['<SOS>']
    new_step.extend(step_tokenized)
    new_step.append('<EOS>')
    return new_step

def to_idx_repr(tokenized_instruction):
    idx_list = [word2idx[w] if w in word2idx else word2idx['<LN>'] for w in tokenized_instruction]
    instr_tensors = torch.tensor(idx_list).view(-1, 1)
    return instr_tensors
    

def prepare_input_instruction(text):
    tokenized = tokenize(text)
    tokenized_h = add_helper_tokens(tokenized)
    tensor = to_idx_repr(tokenized_h)
    return tensor


def remove_helper_tokens(text):
    helpers_r = r'(<SOS>)|(<EOS>)'
    cleaned_text = re.sub(helpers_r, "", text, count=2)
    return cleaned_text


def preprocess_instruction_data_from_recipes(recipes, limit):
    preprocessed = []
    filtered_out = 0
    for rec in recipes:
        rec_steps = []
        use_rec = True
        for step in rec:
            if len(step) < limit:
                tensor_step = prepare_input_instruction(step)
                rec_steps.append(tensor_step)
            else:
                use_rec = False
                filtered_out = filtered_out + 1
        if use_rec:
            preprocessed.append(rec_steps)
    print(filtered_out, " recipes filtered out")
    return preprocessed



def generate_next_steps(first_step):
    print('Input: ', first_step)
    steps = []
    made_up_instruction = first_step
    i = 1
    while len(steps) < 10 and made_up_instruction != "<SOS> <EOS>":
        tensor = prepare_input_instruction(made_up_instruction)
        made_up_instruction = evaluate_with_given_input(tensor)
        steps.append(made_up_instruction)
        print(i,".", remove_helper_tokens(made_up_instruction))
        i = i + 1
        

def get_instruction_steps(recipes):
    recipe_step_pairs = []
    for recipe in recipes:
        for i, instr_step in enumerate(recipe[:-1]):
            recipe_step_pairs.append((instr_step, recipe[i+1]))
    print("Recipe step pairs: ", len(recipe_step_pairs))
    return recipe_step_pairs




#made_up_instruction = "chicken Italian-seasoned bread crumbs small onion cloves garlic taste oil Mix ground chicken , 1/4 cup bread crumbs , onion , egg , garlic , salt , and black pepper in a bowl . Moisten hands and shape chicken mixture , 2 tablespoons at a time , into flat , oval-shaped patties ."
#generate_next_steps(made_up_instruction)

loss_function = nn.NLLLoss()
random_evaluate(recipe_step_pairs)
# Out:
# Instruction step <SOS> Use a vegetable mouli to mash the broad beans - this will mash the bean flesh but leave the skins behind . <EOS>
# Next step <SOS> Add some cream , salt , pepper and a hint of sugar . <EOS>
# Generated instructions <SOS> Place the egg whites in a large bowl and whisk until stiff peaks form . Fold in the whites , <EOS>
# Loss:  10.490737915039062
#
# Instruction step <SOS> Preheat oven to 400 degrees F ( 200 degrees C ) . Lightly spray a 9x13-inch baking dish with vegetable oil . <EOS>
# Next step <SOS> Beat sweet potatoes , white sugar , eggs , milk , 1/2 cup melted butter , vanilla extract , and cinnamon together in a bowl using an electric mixer until smooth ; pour into the prepared baking dish . <EOS>
# Generated instructions <SOS> Place bread cubes in a large bowl , Spread bread mixture on bread mixture into a shallow baking dish and bake for 15 minutes , or until potatoes are tender . <EOS>
# Loss:  9.764098376762576
#
# Instruction step <SOS> Cut broccoli and cauliflower into small to medium florets ; combine with apples and oranges . <EOS>
# Next step <SOS> Pour enough dressing over ingredients to coat ; toss and sprinkle with sunflower seeds . Serve immediately or allow to chill and flavors to blend . <EOS>
# Generated instructions <SOS> Refrigerate until ready to serve . <EOS>
# Loss:  8.545946393694196
#
# Instruction step <SOS> Heat oil in a large skillet over medium heat . Place chicken in oil and cook to brown . Then stir in green peppers and onions ; cook about 4 minutes . Stir in potato , coconut milk , curry sauce , salt , and 3/4 cup water . <EOS>
# Next step <SOS> Mix together cornstarch and 1/4 cup water . Stir into skillet , and simmer 10 minutes . <EOS>
# Generated instructions <SOS> Pour mixture into a 9x13 inch baking dish . Cover with lid and bake 15 minutes , or until chicken is cooked through . <EOS>
# Loss:  11.380978232935854
#
# Instruction step <SOS> Dip each ravioli in the egg mixture , then into the RITZ cracker crumbs . Be sure each ravioli is evenly coated with cracker crumbs . Shake off any excess . <EOS>
# Next step <SOS> Once the oil is hot enough , add small batches of the RITZ cracker-coated ravioli into the oil . Fry for approximately 1 minute on each side . Watch closely so they do not burn ; they cook quickly . When ravioli are golden brown on each side , remove from the oil and place on a paper towel-lined plate to drain . <EOS>
# Generated instructions <SOS> Heat the oil in a skillet over medium-high heat . Cook and stir the onion , celery , celery , celery , celery , celery , celery , celery , celery , celery , celery , green onions , garlic , salt , and pepper in Cook until the onion is translucent , about 5 minutes . Stir in the onion , celery , and parsley , Cook ,
# Loss:  11.765850360576923
#
# Instruction step <SOS> In a clean bowl , whisk the egg whites with a pinch of salt , until soft peaks form when the whisk is removed . <EOS>
# Next step <SOS> Place one third of the egg whites into the béchamel mixture and stir well . <EOS>
# Generated instructions <SOS> Add the egg whites , the cream and vanilla and mix well . <EOS>
# Loss:  7.0214700137867645
#
# Instruction step <SOS> Add the sour cream , basil , garlic , lemon juice , red pepper flakes and a pinch of salt and pepper into the blender and process until smooth . <EOS>
# Next step <SOS> Taste and add salt and lemon juice if needed . If the mixture is too thick , add a teaspoon of water and blend until smooth . <EOS>
# Generated instructions <SOS> Pour the mixture into a clean pan and bake for 30 minutes , or until the top is hot and bubbling . <EOS>
# Loss:  10.662328259698276
#
# Instruction step <SOS> Preheat oven to 425 degrees F ( 220 degrees C ) . On a lightly floured surface , roll out pie crusts , and set aside . In a large bowl , toss apples with lemon juice ; set aside . <EOS>
# Next step <SOS> Combine 1/4 cup brown sugar , butter and corn syrup ; spread in bottom of a 9 inch pie dish ( glass or ceramic works best ) . Sprinkle with chopped pecans . Cover with one pie crust . In a small bowl , mix together 1/2 cup brown sugar , flour , and cinnamon . <EOS>
# Generated instructions <SOS> In a large bowl , mix together the flour , sugar , salt , and sugar . Stir in the eggs , and mix well . Stir in the flour mixture and mix well . <EOS>
# Loss:  10.748629865975216
#
# Instruction step <SOS> Mix sugar , oil , eggs , vanilla extract , salt , baking powder , purple yam powder , and flour , in this order , in a large bowl until dough is well blended . Drop tablespoons of dough onto the baking sheet . <EOS>
# Next step <SOS> Bake in the preheated oven until cookies look firm , 8 to 10 minutes . Cool for at least 5 minutes before gently transferring to a wire rack . <EOS>
# Generated instructions <SOS> Bake in preheated oven for 30 minutes , until the top is puffed and golden brown . about 15 minutes . <EOS>
# Loss:  9.604091521232359
#
# Instruction step <SOS> Mix potatoes , salmon , and capers into kale ; cook and stir until heated through , 3 to 5 minutes . <EOS>
# Next step <SOS> Set oven rack about 6 inches from the heat source and preheat the oven 's broiler . <EOS>
# Generated instructions <SOS> Stir eggs , sugar , salt , and black pepper together in a bowl until mixture is thick and smooth . about 5 minutes . <EOS>
# Loss:  14.463011089124178

# %%
cookstr = [json.loads(line) for line in open('../../original_data/cookstr-recipes.json', 'r')]

# %%
test_recs = [rec['instructions'] for rec in cookstr]
limit = 120
prcessed = preprocess_instruction_data_from_recipes(test_recs, limit)
prcessed = [r for r in prcessed if len(r) > 0]


test_data_steps = get_instruction_steps(prcessed)
# Out:
# 26620  recipes filtered out
# Recipe step pairs:  469

# %%
total_loss = 0

for t in test_data_steps:
    output, loss, attention = evaluate_with_given_input(t)
    total_loss += loss
    
print("Average loss for test set: ", total_loss/len(test_data_steps))
# Out:
# Average loss for test set:  17.362350101664216

# %%
random_evaluate(test_data_steps)
# Out:
# Instruction step <SOS> When fish is seasoned , drain and discard marinade . <EOS>
# Next step <SOS> Grill fish over hot coals until done outside and pink inside ; Do not overcook . <EOS>
# Generated instructions <SOS> Place fish in a large saucepan and heat over medium-high heat until hot but not smoking , about 5 minutes . <EOS>
# Loss:  11.14378187391493
#
# Instruction step <SOS> slightly thinner than you would for a regular pie . <EOS>
# Next step <SOS> Cut into pieces and press into jars three-fourths of <EOS>
# Generated instructions <SOS> Bake in preheated oven for 30 minutes , or until lightly browned on top . <EOS>
# Loss:  16.588165283203125
#
# Instruction step <SOS> In a wok , heat extra virgin olive oil and add onion and ginger . Sauté for about three minutes over medium heat . <EOS>
# Next step <SOS> Add mushrooms and cook until moisture evaporates ( about three minutes ) . <EOS>
# Generated instructions <SOS> Add the rice , stir well . Cook , stirring constantly , until the onion is translucent . about 5 minutes . Stir in the chopped parsley and parsley . Cook , stirring constantly , until the onion is translucent . about 5 minutes . Stir in the chopped parsley and parsley . Cook , stirring constantly , until the onion is translucent . about 5 minutes . <EOS>
# Loss:  43.3228271484375
#
# Instruction step <SOS> Bake for 20 minutes ; turn plantains ; bake for another 20 minutes . <EOS>
# Next step <SOS> Melt margarine . <EOS>
# Generated instructions <SOS> Meanwhile , in a saucepan , combine sugar , cornstarch , and salt and heat until hot . Add eggs , stir until well blended . Remove from heat and stir in vanilla . <EOS>
# Loss:  75.74598999023438
#
# Instruction step <SOS> Prepare the pie dough and chill it . <EOS>
# Next step <SOS> In a mixing bowl , mix the blueberries with the sugar and tapioca . <EOS>
# Generated instructions <SOS> Bake in preheated oven for 20 minutes , or until the top is very light brown . <EOS>
# Loss:  12.66025447845459
#
# Instruction step <SOS> When ready to serve , whisk in the buttermilk , adjust the seasoning . <EOS>
# Next step <SOS> Serve in chilled bowls , with a sprinkling of the chopped chives and a grind of black pepper . <EOS>
# Generated instructions <SOS> Place the cooked onion , carrot , parsley , sugar , chilli , and salt into the oven and cook for two minutes , or until the volume of liquid has reduced by half . <EOS>
# Loss:  14.918583461216517
#
# Instruction step <SOS> When you ’ re ready to cook , thread the lime wedges and scallops on <LN> lime wedge , then 3 scallops , etc . <EOS>
# Next step <SOS> Cook under the broiler or over a charcoal grill for 5 or 6 minutes , turning once . <EOS>
# Generated instructions <SOS> For the salad , heat the oil in a frying pan and fry the onion for 4-5 minutes , or until softened . <EOS>
# Loss:  11.514209747314453
#
# Instruction step <SOS> Preheat broiler . <EOS>
# Next step <SOS> Rub the salmon with a bit of extra virgin olive oil and kosher salt . <EOS>
# Generated instructions <SOS> Place bread cubes in a large bowl , toss with olive oil , salt , and pepper in Spread on top of bread mixture and top with remaining bread slices . <EOS>
# Loss:  15.358793370863971
#
# Instruction step <SOS> As the oysters open , remove with long tongs . Pry open with a knife and eat immediately . <EOS>
# Next step <SOS> The oysters will have a pungent , smoky flavor . <EOS>
# Generated instructions <SOS> For the salad , mix the dressing , sugar , salt , and pepper in a bowl and mix well . <EOS>
# Loss:  17.635155995686848
#
# Instruction step <SOS> When moisture starts to cook out of mushrooms add tofu and spices . <EOS>
# Next step <SOS> Cook , stirring constantly , until heated through ( about 2 minutes ) . <EOS>
# Generated instructions <SOS> Add the rice , stir well . Cook for 5 minutes , or until hot and cooked through . <EOS>
# Loss:  11.066807746887207
