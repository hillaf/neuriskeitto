# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from model import EncoderRNN, AttnDecoderRNN
import json
import helpers


encoder_dict = torch.load('./model_v4.pt', map_location=torch.device('cpu'))['encoder_state_dict']
decoder_dict = torch.load('./model_v4.pt', map_location=torch.device('cpu'))['decoder_state_dict']
    
with open('../project_data/project_train_data_instr.json') as json_file:
    train_data = json.load(json_file)

# %%
N_EPOCHS = 15
LEARNING_RATE = 0.01
REPORT_EVERY = 1000
HIDDEN_DIM = 256
#BATCH_SIZE = 20
#N_LAYERS = 1
teacher_forcing_ratio = 1
TRAIN_SET_SIZE = 1000
n_words = 43863
MAX_LENGTH = 70

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_num_threads(10)

encoder = EncoderRNN(n_words, HIDDEN_DIM).to(device)
decoder = AttnDecoderRNN(HIDDEN_DIM, n_words, max_length=MAX_LENGTH).to(device)

encoder.load_state_dict(encoder_dict)
decoder.load_state_dict(decoder_dict)
# Out:
# <All keys matched successfully>

# %%
encoder.eval()
decoder.eval()

recipe_step_pairs, idx2word, word2idx, ml = helpers.get_tensor_data()
n_words = len(word2idx)
print(recipe_step_pairs[0])
# Out:
# Number of short ingredient lists:  130567
# Average ingredient list length: 14.175872007959267
# No ingredients filtered
# Max instruction step length:  70
# Number of long instructions:  61032
# Average instruction length: 149.95270527301457
# Total instruction steps:  489828
# Recipes filtered:  61455
# Recipes left after filtering:  75241
# Recipe step pairs:  223824
# <SOS> Preheat oven to 400 degrees F ( 205 degrees C ) . Butter a 9x9x2 inch baking pan . <EOS>
# <SOS> Melt 1 tablespoon butter in medium nonstick skillet over medium-low heat . Add onion and saute until tender , about 10 minutes . Cool . <EOS>
# (tensor([[43860],
#         [   17],
#         [   18],
#         [   19],
#         [   20],
#         [   21],
#         [   22],
#         [   23],
#         [   24],
#         [   21],
#         [   25],
#         [   26],
#         [   27],
#         [   28],
#         [   29],
#         [   30],
#         [   31],
#         [   32],
#         [   33],
#         [   27],
#         [43862]]), tensor([[43860],
#         [   34],
#         [   35],
#         [   36],
#         [    1],
#         [   37],
#         [   38],
#         [   39],
#         [   40],
#         [   41],
#         [   42],
#         [   43],
#         [   27],
#         [   44],
#         [    2],
#         [   45],
#         [   46],
#         [   47],
#         [   48],
#         [   49],
#         [   50],
#         [   51],
#         [   52],
#         [   27],
#         [   53],
#         [   27],
#         [43862]]))

# %%
from random import choice
from helpers import idx_to_words
from nltk.tokenize import sent_tokenize, word_tokenize
import re

def evaluate(encoder, decoder, input_tensor, gold_standard):
    with torch.no_grad():
        max_length = MAX_LENGTH
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden(device)

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        loss = 0
        
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[word2idx['<SOS>']]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if di < len(gold_standard):
                loss += loss_function(decoder_output, gold_standard[di])
            else:
                loss += loss_function(decoder_output, gold_standard[-1])
            if topi.item() == word2idx['<EOS>']:
                if di < len(gold_standard) and gold_standard[di] !=  word2idx['<EOS>']:
                    for dj in range(di, len(gold_standard)):
                        loss += loss_function(decoder_output, gold_standard[dj])
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(idx2word[str(topi.item())])

            decoder_input = topi.squeeze().detach()

        return decoded_words, loss.item()/len(gold_standard), decoder_attentions

    
def random_evaluate(evaluation_data, n=10):
    for i in range(n):
        pair = choice(evaluation_data)
        print('Instruction step', idx_to_words(pair[0], idx2word))
        print('Next step', idx_to_words(pair[1], idx2word))
        output_words, loss, attentions = evaluate(encoder, decoder, pair[0].to(device), pair[1].to(device))
        output_sentence = ' '.join(output_words)
        print('Generated instructions', output_sentence)
        print("Loss: ", loss)
        print('')
        
        
def evaluate_with_given_input(pair):
    #print('Instruction step', idx_to_words(pair[0], idx2word))
    #print('Next step', idx_to_words(pair[1], idx2word))
    output_words, loss, attentions = evaluate(encoder, decoder, pair[0].to(device), pair[1].to(device))
    output_sentence = ' '.join(output_words)
    #print('Generated instructions', output_sentence)
    return output_sentence, loss, attentions

    
def tokenize(instruction_step):
    words_tokenized = word_tokenize(instruction_step)
    return words_tokenized


def add_helper_tokens(step_tokenized):
    new_step = ['<SOS>']
    new_step.extend(step_tokenized)
    new_step.append('<EOS>')
    return new_step

def to_idx_repr(tokenized_instruction):
    idx_list = [word2idx[w] if w in word2idx else word2idx['<LN>'] for w in tokenized_instruction]
    instr_tensors = torch.tensor(idx_list).view(-1, 1)
    return instr_tensors
    

def prepare_input_instruction(text):
    tokenized = tokenize(text)
    print(tokenized)
    tokenized_h = add_helper_tokens(tokenized)
    tensor = to_idx_repr(tokenized_h)
    return tensor


def prepare_input_instruction_eval(text):
    tokenized = tokenize(text)
    tokenized_h = add_helper_tokens(tokenized[3:-3])
    tensor = to_idx_repr(tokenized_h)
    return tensor


def remove_helper_tokens(text):
    helpers_r = r'(<SOS>)|(<EOS>)'
    cleaned_text = re.sub(helpers_r, "", text, count=2)
    return cleaned_text


def preprocess_instruction_data_from_recipes(recipes, limit):
    preprocessed = []
    filtered_out = 0
    for rec in recipes:
        rec_steps = []
        use_rec = True
        for step in rec:
            if len(step) < limit:
                tensor_step = prepare_input_instruction(step)
                rec_steps.append(tensor_step)
            else:
                use_rec = False
                filtered_out = filtered_out + 1
        if use_rec:
            preprocessed.append(rec_steps)
    print(filtered_out, " recipes filtered out")
    return preprocessed



def generate_next_steps(first_step):
    print('Input: ', first_step)
    steps = []
    made_up_instruction = first_step
    i = 1
    while len(steps) < 10 and made_up_instruction != "<SOS> <EOS>":
        tensor = prepare_input_instruction(made_up_instruction)
        made_up_instruction = evaluate_with_given_input(tensor)
        steps.append(made_up_instruction)
        print(i,".", remove_helper_tokens(made_up_instruction))
        i = i + 1
        

def get_instruction_steps(recipes):
    recipe_step_pairs = []
    for recipe in recipes:
        for i, instr_step in enumerate(recipe[:-1]):
            recipe_step_pairs.append((instr_step, recipe[i+1]))
    print("Recipe step pairs: ", len(recipe_step_pairs))
    return recipe_step_pairs




#made_up_instruction = "chicken Italian-seasoned bread crumbs small onion cloves garlic taste oil Mix ground chicken , 1/4 cup bread crumbs , onion , egg , garlic , salt , and black pepper in a bowl . Moisten hands and shape chicken mixture , 2 tablespoons at a time , into flat , oval-shaped patties ."
#generate_next_steps(made_up_instruction)

loss_function = nn.NLLLoss()
random_evaluate(recipe_step_pairs)
# Out:
# Instruction step <SOS> 3 . Add the broccoli florets , salt and coconut milk , bring to a boil , reduce to medium and cook for 5 minutes . <EOS>
# Next step <SOS> 4 . Add the noodles to the coconut milk mixture and toss to thoroughly coat . <EOS>
# Generated instructions <SOS> 4 . Pour the mixture into the hot skillet and cook for 5 minutes , or until the onion is translucent . <EOS>
# Loss:  11.131607055664062
#
# Instruction step <SOS> In a large bowl , combine the heavy cream and the half and half . Gradually whisk in the sugar until blended . <EOS>
# Next step <SOS> Whisk in the vanilla . Refrigerate , covered , until very cold , at least 3 hours or as long as 3 days . <EOS>
# Generated instructions <SOS> Add the cream cheese , the cream cheese , and cheese ; mix well . <EOS>
# Loss:  9.638291579026442
#
# Instruction step <SOS> Cut each dough ball in half , and cut each half into 12 pieces ( 96 total pieces ) . Working in batches , press each small piece of dough into the bottom and up the sides of mini muffin cups . Fill the little crusts almost to the top with the pumpkin filling . Refrigerate unused dough until you need it to make the next batch . <EOS>
# Next step <SOS> Bake in the preheated oven until the filling is set and the crusts are lightly golden brown , 25 to 30 minutes . Allow to cool completely before frosting . <EOS>
# Generated instructions <SOS> Roll out dough to a thickness of a circle . <EOS>
# Loss:  9.069737434387207
#
# Instruction step <SOS> Mix cake mix , dried cranberries , vegetable oil , and eggs together in a bowl until dough is smooth . Drop 1 to 2 tablespoons batter per cookie onto a baking sheet . <EOS>
# Next step <SOS> Bake in the preheated oven until cooked through , 6 to 10 minutes . Cool cookies on baking sheet for about 5 minutes ; transfer to a sheet of waxed paper to cool completely . <EOS>
# Generated instructions <SOS> Bake in preheated oven for 30 minutes , until the top is puffed and browned on top , about 5 minutes . <EOS>
# Loss:  10.181435249947214
#
# Instruction step <SOS> Add the mussels and white wine , stir well and place the lid on . Allow the mussels to steam for 3-4 minutes , then remove the lid and check that all the mussels are cooked and have opened . Discard any that do not open . <EOS>
# Next step <SOS> Allow to cool slightly then remove the mussels from their shells . Discard the shells and return the mussels to the pan . <EOS>
# Generated instructions <SOS> To serve , spoon the couscous in a serving bowl and pour over the salad . <EOS>
# Loss:  8.584424438476562
#
# Instruction step <SOS> Preheat oven to 350°F with rack in middle . <EOS>
# Next step <SOS> Put cajeta , half-and-half , and lime zest in a heavy medium saucepan . Split vanilla bean lengthwise and scrape seeds into saucepan , then drop in pod . Bring to a simmer , stirring until smooth . <EOS>
# Generated instructions <SOS> Put bread cubes in a baking dish and bake in preheated oven for 15 minutes , or until potatoes are tender . <EOS>
# Loss:  10.954741668701171
#
# Instruction step <SOS> Stir the soup , milk and beans in the skillet . <EOS>
# Next step <SOS> Stir the stuffing and cheese in a small bowl . Sprinkle around the inside edge of the skillet . <EOS>
# Generated instructions <SOS> Cover with water and cook for 30 minutes . or until the top is hot and the top is bubbly . <EOS>
# Loss:  8.396977015904017
#
# Instruction step <SOS> Discard tea bags and cinnamon stick and transfer tea to a pitcher . Chill tea , covered at least 12 hours and up to 1 day . Remove ginger and cloves with a slotted spoon and discard . Stir in rum and orange slices . <EOS>
# Next step <SOS> Serve punch over ice in stemmed glasses . <EOS>
# Generated instructions <SOS> Serve immediately . <EOS>
# Loss:  4.682122802734375
#
# Instruction step <SOS> Combine chiles , coriander seeds , fennel seeds , and cumin seeds in small bowl . Add cold water to cover , then drain . Place drained mixture in heavy small skillet . Dry-roast over medium-low heat until seeds are dry , slightly darker in color , and beginning to pop , stirring occasionally , 3 to 4 minutes . Cool in skillet . <EOS>
# Next step <SOS> Place mace , white pepper , and turmeric in spice mill or grinder . Add cooled spice mixture . Grind to powder . DO AHEAD : Can be made 1 week ahead . Store airtight at room temperature . <EOS>
# Generated instructions <SOS> Combine flour , salt , and baking soda , large bowl ; Add to shortening mixture . beat well . Add eggs , beating well after each addition . Stir in flour mixture alternately with buttermilk , mixing just until moistened . Stir in walnuts . <EOS>
# Loss:  11.6704555604516
#
# Instruction step <SOS> Preheat oven to 350°F . Spread out pistachios on a small rimmed baking sheet ; toast , stirring occasionally until golden brown , 6-8 minutes . Let cool ; coarsely chop . <EOS>
# Next step <SOS> Combine garlic , raisins , and vinegar in a large bowl ; let sit 1 hour . <EOS>
# Generated instructions <SOS> Meanwhile , in a large bowl , combine sugar , butter , and salt in large bowl until just combined . Add eggs , beat well . Stir in flour mixture , <EOS>
# Loss:  16.731948049444902

# %%
cookstr = [json.loads(line) for line in open('../../original_data/cookstr-recipes.json', 'r')]

# %%
test_recs = [rec['instructions'] for rec in cookstr]
limit = 120
prcessed = preprocess_instruction_data_from_recipes(test_recs, limit)
prcessed = [r for r in prcessed if len(r) > 0]


test_data_steps = get_instruction_steps(prcessed)
# Out:
# ['The', 'juice', 'mixture', 'will', 'give', 'the', 'cake', 'a', 'lovely', ',', 'fresh', ',', 'fruity', 'flavor', 'and', 'it', 'is', 'not', 'rich', 'like', 'an', 'icing', '.']
# ['Leave', 'the', 'cake', 'to', 'cool', '.']
# ['Preheat', 'a', 'gas', 'grill', 'or', 'prepare', 'a', 'fire', 'in', 'a', 'charcoal', 'grill', '.']
# ['Serve', 'immediately', 'with', 'a', 'sprinkling', 'of', 'pepper', ',', 'the', 'cilantro', ',', 'a', 'dollop', 'of', 'yogurt', ',', 'and', 'some', 'hunks', 'of', 'bread', '.']
# ['Cool', 'the', 'génoise', 'layer', '.']
# ['<', 'p', '>', '<', 'b', '>', 'Serving', '<', '/b', '>', ':', 'Cut', 'diagonal', 'slices', 'to', 'serve.', '<', '/p', '>']
# ['<', 'p', '>', '<', 'b', '>', 'Storage', '<', '/b', '>', ':', 'Refrigerate', 'the', 'cake', 'until', 'immediately', 'before', 'serving.', '<', '/p', '>']
# ['To', 'make', 'Scorch', ',', 'omit', 'the', 'tomatoes', 'and', 'bell', 'peppers', 'from', 'the', 'salad', 'and', 'double', 'the', 'amount', 'of', 'habanero', 'and', 'bird', 'chiles', '.']
# ['Preheat', 'a', 'barbecue', 'grill', 'to', 'high', 'heat', '.']
# ['Stir', 'the', 'butter', 'and', 'the', 'chile', 'powder', 'together', 'in', 'a', 'small', 'bowl', ',', 'and', 'set', 'it', 'aside', '.']
# ['Preheat', 'grill', 'to', 'medium-high', 'or', '350', 'to', '400', 'F.', 'if', 'not', 'already', 'hot', '.']
# ['Place', 'peach', 'halves', 'on', 'grill', ',', 'cut', 'side', 'down', ',', 'and', 'grill', 'about', '5', 'minutes', 'or', 'until', 'flesh', 'has', 'slightly', 'charred', '.']
# ['Brush', 'top', 'sides', 'with', 'glaze', 'and', 'cook', '1', 'to', '2', 'minutes', '.']
# ['Turn', ',', 'brush', 'with', 'glaze', 'and', 'cook', 'another', '2', 'to', '3', 'minutes', '.']
# ['Transfer', 'to', 'individual', 'serving', 'dishes', 'and', 'spoon', 'any', 'remaining', 'glaze', 'of', 'tops', '.']
# ['Serve', 'with', 'crumbled', 'cheese', 'on', 'top', '.']
# ['Heat', 'the', 'oven', 'to', '325°F', '.']
# ['Place', 'the', 'chicken', 'in', 'a', 'deep', 'baking', 'dish', 'and', 'roast', 'for', 'about', '3', 'to', '4', 'hours', ',', 'basting', 'halfway', 'through', 'the', 'roasting', 'time', '.']
# ['Remove', 'from', 'oven', 'and', 'let', 'rest', 'about', '15', 'minutes', '.', 'Slice', 'into', 'pieces', 'and', 'serve', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '(', '180°C', ')', '.', 'Butter', 'and', 'flour', 'the', 'pan', ',', 'tapping', 'out', 'the', 'excess', 'flour', '.']
# ['Cool', 'in', 'the', 'pan', 'for', '10', 'minutes', ',', 'then', 'remove', '.', 'Dust', 'with', 'confectioner', "'s", 'sugar', 'and', 'serve', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.', 'Butter', 'two', '9-x-5-inch', 'bread', 'pans', 'and', 'set', 'aside', '.']
# ['Wash', ',', 'and', 'dry', 'the', 'turkey', 'thoroughly', '.', 'Remove', 'the', 'wing', 'tips', ',', 'and', 'chop', 'the', 'gizzard', 'and', 'heart', '.']
# ['Meanwhile', ',', 'stuff', 'and', 'truss', 'the', 'turkey', '.']
# ['Strain', 'the', 'gravy', 'into', 'a', 'saucepan', 'and', 'keep', 'warm', 'until', 'ready', 'to', 'serve', 'with', 'the', 'bird', '.']
# ['Cook', 'the', 'bucatini', 'according', 'to', 'the', 'directions', 'on', 'the', 'package', '.', 'Drain', 'and', 'transfer', 'to', 'a', 'large', 'bowl', '.', 'Set', 'aside', '.']
# ['Preheat', 'the', 'oven', 'to', '325°F', '.']
# ['Mix', 'the', 'ricotta', 'with', 'the', 'egg', ',', 'the', 'spinach', ',', 'and', 'the', 'pesto', 'and', 'set', 'aside', '.']
# ['Sandwich', 'Loaf', ':']
# ['Savory', 'Challah', ':']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Remove', 'the', 'steaks', 'from', 'the', 'refrigerator', '30', 'to', '40', 'minutes', 'before', 'cooking', '.', 'Cover', 'loosely', 'with', 'plastic', 'wrap', '.']
# ['Oil', 'the', 'grill', 'racks', '.', 'Preheat', 'your', 'grill', 'using', 'all', 'burners', 'set', 'on', 'high', 'and', 'with', 'the', 'lid', 'closed', 'for', '10', 'to', '12', 'minutes', '.']
# ['Dishes', 'that', 'call', 'for', 'achiote', 'oil', ':', 'Noodle', 'Paella']
# ['Preheat', 'oven', 'to', '350°F', '(', '175°C', ')', '.']
# ['Brush', '2', 'tablespoons', 'of', 'the', 'coconut', 'or', 'olive', 'oil', 'on', 'the', 'bottom', 'of', 'a', 'large', 'roasting', 'pan', 'or', 'baking', 'dish', '.']
# ['Cut', 'the', 'squash', 'in', 'half', 'and', 'remove', 'the', 'seeds', 'and', 'pulp', 'with', 'a', 'tablespoon', '.', 'Place', 'in', 'the', 'prepared', 'pan', '.']
# ['Place', 'the', 'ground', 'chicken', 'in', 'a', 'large', 'mixing', 'bowl', 'and', 'set', 'aside', '.']
# ['Add', 'the', 'garlic', 'and', 'cook', 'for', '1', 'minute', 'more', ',', 'then', 'remove', 'from', 'heat', 'and', 'let', 'cool', '.']
# ['Scoop', 'the', 'mixture', 'into', 'the', '4', 'acorn', 'halves', ',', 'distributing', 'evenly', '.']
# ['Bake', 'for', '1', 'hour', 'and', 'enjoy', '!']
# ['Preheat', 'oven', 'to', '350°F', '(', '180°C', ')']
# ['Fill', 'squash', 'cavities', 'with', 'chickpea', 'mixture', '.']
# ['Spoon', 'into', 'a', 'small', 'serving', 'dish', 'and', 'top', 'with', 'scallion', '.', 'Serve', 'with', 'sesame', 'crackers', '.']
# ['Chop', 'the', 'cilantro', '.']
# ['Mince', 'the', 'onion', '.']
# ['Cut', 'the', 'fish', 'into', 'small', 'pieces', '.']
# ['Heat', 'the', 'olive', 'oil', 'in', 'a', 'large', 'frying', 'pan', 'over', 'medium', 'heat', '.', 'Add', 'the', 'onion', ',', 'fish', ',', 'chili', 'powder', ',', 'and', 'garlic', 'salt', '.']
# ['Stir', 'the', 'ingredients', 'with', 'a', 'wooden', 'spoon', '.', 'As', 'the', 'fish', 'begins', 'to', 'cook', ',', 'use', 'the', 'spoon', 'to', 'break', 'it', 'into', 'flakes', '.']
# ['In', 'a', 'shallow', 'bowl', ',', 'sprinkle', 'bread', 'with', 'water', 'until', 'soaked', ',', 'then', 'squeeze', 'dry', '.']
# ['On', 'low', 'speed', ',', 'add', 'lemon', 'juice', '.', 'Thin', 'with', 'cold', 'water', 'as', 'necessary', 'for', 'desired', 'consistency', '.']
# ['Make', 'ahead', ':', 'Cover', 'and', 'refrigerate', 'for', 'up', 'to', '1', 'week', '.']
# ['Variation', ':', 'Roasted', 'Garlic', 'Aïoli']
# ['Variation', ':', 'Apple', 'Aïoli']
# ['Variations', ':']
# ['Omit', 'the', 'turnip', 'and', 'add', '2', 'pounds', 'peeled', ',', 'chopped', 'parsnips', '.']
# ['Omit', 'the', 'turnip', 'and', 'add', 'a', '2-pound', 'winter', 'squash', ',', 'peeled', 'and', 'chopped', '.']
# ['Add', '6', 'peeled', 'whole', 'garlic', 'cloves', 'to', 'the', 'pot', 'with', 'the', 'potatoes', 'and', 'turnips', 'for', 'a', 'garlic-flavored', 'dish', '.']
# ['Soak', 'rice', 'in', 'water', ',', 'enough', 'to-cover', ',', 'for', '30', 'minutes', '.', 'Drain', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.', 'Butter', 'an', '8', 'x', '8-inch', 'glass', 'pan', '.', 'Set', 'aside', '.']
# ['In', 'a', 'large', 'bowl', ',', 'mix', 'together', 'the', 'milk', ',', 'eggs', ',', 'salt', ',', 'and', 'pepper', '.', 'In', 'a', 'medium-size', 'bowl', ',', 'toss', 'the', 'cheeses', 'together', '.']
# ['Preheat', 'the', 'oven', 'to', '375', 'degrees', '.']
# ['Line', '2', 'cookie', 'sheets', 'with', 'nonstick', 'silicone', 'liners', 'or', 'parchment', 'paper', '.', 'Set', 'aside', '.']
# ['Sift', 'the', 'flour', ',', 'baking', 'soda', ',', 'and', 'salt', 'together', 'and', 'set', 'aside', '.']
# ['Place', 'the', 'butter', 'in', 'the', 'bowl', 'of', 'an', 'electric', 'mixer', 'and', 'beat', 'until', 'smooth', '.']
# ['Add', 'the', 'sugar', 'and', 'vanilla', 'and', 'beat', 'for', 'about', '5', 'minutes', ',', 'or', 'until', 'the', 'mixture', 'is', 'light', 'and', 'creamy', '.']
# ['Add', 'the', 'flour', 'mixture', ',', 'beating', 'to', 'blend', 'well', '.', 'Fold', 'the', 'chocolate', 'chips', 'and', 'nuts', ',', 'if', 'using', ',', 'into', 'the', 'dough', '.']
# ['Place', 'them', 'in', 'the', 'preheated', 'oven', 'and', 'bake', 'for', '15', 'minutes', ',', 'or', 'until', 'they', 'are', 'golden', 'brown', 'and', 'set', 'in', 'the', 'middle', '.']
# ['Using', 'a', 'spatula', ',', 'lift', 'the', 'cookies', 'onto', 'wire', 'racks', 'to', 'cool', 'for', 'about', '10', 'minutes', '.']
# ['You', 'can', 'store', 'them', ',', 'tightly', 'covered', ',', 'for', 'up', 'to', '3', 'days', '.']
# ['Rosemary', 'Semolina', 'Double', 'Crust', ':']
# ['Hand', 'Method']
# ['Food', 'Processor', 'Method']
# ['Turn', 'out', 'dough', 'onto', 'a', 'clean', 'surface', 'and', 'gather', 'into', 'a', 'ball', '.', 'Proceed', 'with', 'Step', '3', 'above', '.']
# ['Variations', ':']
# ['Flaky', 'Pie', 'Pastry', 'Dough', ':']
# ['In', 'a', 'medium-size', 'bowl', ',', 'mix', 'the', 'flour', 'and', 'salt', 'together', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.', 'Butter', 'and', 'lightly', 'flour', 'two', '8-inch', 'round', 'cake', 'pans', '.']
# ['Make', 'the', 'cake', ':', 'Place', 'the', 'cocoa', 'in', 'a', 'small', 'bowl', 'and', 'whisk', 'in', 'the', 'boiling', 'water', 'to', 'form', 'a', 'paste', '.']
# ['Mix', 'all', 'the', 'ingredients', 'together', 'to', 'blend', '.', 'Store', 'in', 'the', 'refrigerator', 'in', 'a', 'tightly', 'closed', 'container', 'for', 'up', 'to', '2', 'weeks', '.']
# ['Store', 'in', 'an', 'airtight', 'container', 'for', 'up', 'to', '1', 'month', '.']
# ['.']
# ['2', ')', '.', 'Add', 'the', 'onion', 'and', 'sauté', 'for', 'about', '8', 'minutes', ',', 'or', 'until', 'soft', '.']
# ['4', ')', '.', 'Toss', 'in', 'the', 'lemon', 'juice', ',', 'and', 'add', 'black', 'pepper', '(', 'and', 'possibly', 'more', 'salt', ')', 'to', 'taste', '.']
# ['5', ')', '.', 'Serve', 'hot', ',', 'warm', ',', 'or', 'at', 'room', 'temperature', '.']
# ['Variation', ':', 'If', 'you', 'like', 'more', 'of', 'a', 'crust', 'on', 'your', 'burgers', ',', 'coat', 'them', 'with', 'additional', 'ground', 'oats', 'before', 'pan-frying', 'them', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Bake', 'until', 'the', 'almond', 'mixture', 'has', 'browned', 'slightly', 'and', 'the', 'fish', 'is', 'cooked', 'through', 'and', 'flakes', 'easily', ',', 'about', '15', 'minutes', '.']
# ['Position', 'a', 'rack', 'in', 'the', 'center', 'of', 'the', 'oven', 'and', 'preheat', 'the', 'oven', 'to', '350°F', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.', 'Lightly', 'grease', '2', 'round', '8-inch', 'pans', 'preferably', 'non-stick', '.']
# ['Dust', 'liberally', 'with', 'confectioners', '’', 'sugar', 'before', 'serving', '.']
# ['Preheat', 'oven', 'to', '325°F', '(', '160°C', ')', '.']
# ['In', 'a', 'small', 'bowl', ',', 'mix', 'together', 'almond', 'meal', ',', 'flour', ',', 'coconut', 'and', 'salt', '.', 'Add', 'to', 'chocolate', 'mixture', ',', 'stirring', 'until', 'smooth', '.']
# ['Variation', ':', 'Top', 'batter', 'with', '½', 'cup', '(', '125', 'mL', ')', 'chopped', 'chocolate', 'or', 'chocolate', 'chips', 'before', 'baking', '.']
# ['In', 'a', 'small', 'bowl', ',', 'combine', 'the', 'mangoes', ',', '¼', 'cup', 'olive', 'oil', ',', 'lime', 'juice', ',', 'zest', ',', 'salt', ',', 'and', 'pepper', '.', 'Chill', 'until', 'ready', 'to', 'use', '.']
# ['Preheat', 'the', 'oven', 'to', '350', 'degrees', 'F', 'and', 'line', '2', 'baking', 'sheets', 'with', 'parchment', 'paper', '.']
# ['Serving', 'suggestion', ':', 'Spread', 'filling', 'in', 'unbaked', 'turnovers', 'or', 'tart', 'or', 'tartlet', 'shells', 'as', 'directed', 'in', 'recipe', '.']
# ['Preheat', 'the', 'oven', 'to', '325°F', '.', 'Line', '2', 'baking', 'sheets', 'with', 'parchment', 'paper', '.']
# ['Store', 'in', 'an', 'airtight', 'container', 'for', 'up', 'to', '3', 'days', 'or', 'freeze', 'for', 'up', 'to', '2', 'months', '.']
# ['Drain', 'the', 'almonds', 'and', 'place', 'them', 'and', 'the', 'water', 'in', 'the', 'blender', '.', 'Blend', 'on', 'the', 'highest', 'setting', 'for', 'a', 'full', '2', 'minutes', '.']
# ['The', 'milk', 'is', 'ready', 'to', 'drink', 'immediately', ':', 'try', 'it', 'straight', 'up', 'or', 'over', 'ice', '.']
# ['Kept', 'refrigerated', ',', 'almond', 'milk', ':', 'will', 'last', 'for', '5', 'days', '.', 'Frozen', ',', 'it', 'will', 'last', 'for', 'up', 'to', '4', 'months', '.']
# ['Break', 'the', 'roca', 'into', 'irregular', 'pieces', '.', 'Store', 'in', 'an', 'airtight', 'container', 'at', 'room', 'temperature', 'or', 'freeze', 'for', 'longer', 'storage', '.']
# ['Knead', 'for', 'a', 'minute', 'or', 'two', ',', 'until', 'smooth', ',', 'on', 'a', 'lightly', 'floured', 'board', '.', 'Wrap', 'in', 'waxed', 'paper', 'and', 'chill', 'for', '2', 'hours', '.']
# ['Cool', 'completely', 'and', 'serve', 'plain', 'or', 'filled', 'with', 'whipped', 'cream', 'and', 'a', 'dab', 'of', 'jam', 'or', 'jelly', '.']
# ['Preheat', 'the', 'oven', 'to', '325°F', '(', '165°C', ')', 'and', 'place', 'a', 'rack', 'on', 'the', 'middle', 'level', '.']
# ['To', 'make', 'the', 'filling', ':']
# ['Crush', 'the', 'coriander', 'seeds', 'in', 'a', 'mortar', 'with', 'a', 'pestle', '.', 'Cut', 'the', 'dried', 'chiles', 'into', 'small', 'pieces', '.']
# ['Transfer', 'to', 'a', 'serving', 'dish', 'and', 'serve', 'hot', '.']
# ['Serve', 'with', 'papadums', '(', 'Indian', 'wafers', ')', 'and', 'prepared', 'coriander', 'chutney', '.']
# ['Season', 'to', 'taste', 'and', 'decant', 'to', 'a', 'warmed', 'dish', '.']
# ['Position', 'your', 'oven', 'racks', 'so', 'that', 'one', 'is', 'in', 'the', 'center', ',', 'and', 'preheat', 'the', 'oven', 'to', '375', 'degrees', '.']
# ['Using', 'either', 'a', 'knife', 'or', 'a', 'mandoline', ',', 'slice', 'the', 'apples', 'thin', '(', '1/8', 'inch', ')', 'lengthwise', '.']
# ['Remove', 'the', 'tart', 'from', 'the', 'oven', ',', 'and', 'set', 'it', 'on', 'a', 'wire', 'rack', 'to', 'cool', 'slightly', '.']
# ['Unmold', 'the', 'polenta', 'onto', 'a', 'cutting', 'board', 'and', 'slice', 'into', 'triangles', 'or', 'bars', '.', 'Reserve', '.']
# ['Serve', 'the', 'polenta', 'on', 'plates', ',', 'topped', 'with', 'the', 'tuna', 'sauce', 'and', 'basil', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.']
# ['Lightly', 'grease', 'three', 'baking', 'sheets', 'with', 'vegetable', 'spray', 'or', 'line', 'with', 'parchment', 'paper', '.']
# ['Bake', 'for', 'about', '15', 'minutes', 'or', 'until', 'the', 'cookies', 'are', 'golden', 'in', 'color', 'and', 'firm', 'to', 'the', 'touch', '.']
# ['Let', 'them', 'cool', 'before', 'removing', 'them', 'from', 'the', 'baking', 'sheets', '.']
# ['Preheat', 'the', 'oven', 'to', '425', 'F.', 'degrees', '.']
# ['Cut', 'two', 'small', 'gashes', 'in', 'the', 'center', 'of', 'the', 'top', 'crust', 'to', 'allow', 'the', 'steam', 'to', 'escape', '.']
# ['VARIATION']
# ['Sprinkle', 'blueberries', 'onto', 'the', 'uncooked', 'side', 'of', 'the', 'pancake', 'just', 'after', 'you', '’', 've', 'poured', 'the', 'batter', 'into', 'the', 'pan', '.']
# ['Ladle', 'the', 'soup', 'into', 'heated', 'soup', 'bowls', 'and', 'dust', 'each', 'one', 'with', 'parsley', '.']
# ['Hot-smoke', 'the', 'ham', 'at', '200', 'degrees', 'F/93', 'C', 'for', '2', 'hours', '.']
# ['Remove', 'the', 'ham', 'from', 'the', 'smoker', 'and', 'brush', 'with', 'the', 'remaining', 'glaze', '.', 'Allow', 'to', 'cool', ',', 'and', 'refrigerate', '.']
# ['Once', 'the', 'filling', 'has', 'cooled', ',', 'transfer', 'it', 'to', 'a', 'container', 'and', 'refrigerate', 'for', 'at', 'least', '1', 'hour', 'or', 'overnight', '.']
# ['.', 'In', 'a', 'bowl', ',', 'combine', 'the', 'vinegar', ',', 'garlic', ',', 'and', 'chiles', 'and', 'serve', 'this', 'dipping', 'sauce', 'with', 'the', 'hot', 'rolls', '.']
# ['Remove', 'the', 'stems', 'and', 'seeds', 'from', 'the', 'chilies', '.', 'Quarter', 'the', 'garlic', 'cloves', '.']
# ['Makes', 'about', '6', 'cups', 'of', 'sauce', '.', 'Extra', 'sauce', 'stores', 'several', 'weeks', 'in', 'the', 'fridge', ',', 'a', 'few', 'months', 'in', 'the', 'freezer', '.']
# ['Cut', 'the', 'baguette', 'in', 'half', 'lengthways', 'and', 'lightly', 'toast', 'on', 'both', 'sides', '.']
# ['Broil', 'for', '2–3', 'minutes', ',', 'or', 'until', 'the', 'mozzarella', 'has', 'melted', '.', 'Serve', 'hot', ',', 'sprinkled', 'with', 'the', 'olives', '.']
# ['Beat', 'the', 'ingredients', 'together', ',', 'then', 'roll', 'in', 'wax', 'paper', 'and', 'chill', '.']
# ['Beat', 'all', 'the', 'ingredients', 'together', ',', 'then', 'roll', 'in', 'wax', 'paper', 'and', 'chill', 'until', 'required', '.']
# ['Put', 'all', 'of', 'the', 'ingredients', 'into', 'a', 'blender', ',', 'and', 'whiz', 'to', 'make', 'the', 'dressing', '.']
# ['Pour', 'into', 'a', 'jam', 'jar', 'and', 'put', 'on', 'the', 'lid', 'to', 'store', '.']
# ['Beat', 'the', 'eggs', 'lightly', 'in', 'a', 'bowl', ',', 'and', 'whisk', 'or', 'stir', 'in', 'the', 'salt', '.']
# ['Add', 'the', 'tomatoes', 'and', 'fry', 'for', 'another', '2', 'to', '3', 'minutes', ',', 'until', 'they', 'are', 'softened', '.']
# ['Then', 'continue', 'to', 'cook', 'for', '2', 'to', '3', 'minutes', 'more', ',', 'until', 'the', 'eggs', 'are', 'well', 'cooked', '.']
# ['Turn', 'out', 'onto', 'a', 'flat', 'plate', 'to', 'serve', ',', 'garnished', 'with', 'the', 'fresh', 'coriander', '.']
# ['Serve', 'with', 'a', 'green', 'salad', 'and', 'Chapatis', '.']
# ['Preheat', 'the', 'oven', 'to', '450°F', '.']
# ['Pour', 'the', 'cake', 'batter', 'into', 'the', 'pan', 'and', 'bake', 'for', '40', 'minutes', '.']
# ['When', 'completely', 'cooled', ',', 'pull', 'the', 'sides', 'away', 'from', 'the', 'pan', 'with', 'a', 'fork', 'and', 'unmold', 'the', 'cake', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '(', '180°C', ')', '.', 'Sift', 'the', 'flour', 'and', 'confectioner', "'s", 'sugar', 'together', '.']
# ['Bake', 'about', '40', 'minutes', ',', 'until', 'the', 'top', 'is', 'golden', 'brown', 'and', 'springs', 'back', 'when', 'pressed', '.']
# ['Transfer', 'the', 'cake', 'to', 'a', 'cake', 'plate', '.']
# ['Bring', 'a', 'large', 'pot', 'of', 'water', 'to', 'a', 'boil', 'over', 'high', 'heat', 'and', 'maintain', 'at', 'a', 'boil', '.']
# ['Champagne', 'or', 'iced', 'vodka', 'accompany', 'this', 'admirably', '.', 'Don', '’', 't', 'stint', 'on', 'the', 'caviar', 'if', 'possible', '!']
# ['Preheat', 'oven', 'to', '350', 'degrees']
# ['Remove', 'from', 'heat', ';', 'cool', '.']
# ['Strain', 'oil', ',', 'discard', 'seeds', ',', 'and', 'store', 'in', 'a', 'jar', 'in', 'refrigerator', 'for', 'later', 'use', '.']
# ['The', 'oil', 'will', 'keep', 'for', 'several', 'months', '.']
# ['In', 'a', 'small', 'skillet', ',', 'heat', 'oil', 'over', 'medium', 'heat', ';', 'combine', 'ingredients', ';', 'sauté', 'lightly', 'for', '5', 'minutes', '.']
# ['If', 'you', 'like', 'your', 'food', 'spicy', ',', 'add', 'chile', 'to', 'taste', '.']
# ['Toast', 'the', 'annatto', 'seeds', 'in', 'a', 'heavy', 'saucepan', 'until', 'they', 'just', 'start', 'to', 'smoke', '.', 'Add', 'the', 'olive', 'oil', '.']
# ['When', 'the', 'oil', 'begins', 'to', 'simmer', ',', 'remove', 'from', 'the', 'heat', 'and', 'allow', 'to', 'cool', '.']
# ['Strain', 'the', 'oil', 'and', 'store', 'in', 'an', 'airtight', 'container', 'in', 'a', 'cool', ',', 'dark', 'place', 'for', 'several', 'months', '.']
# ['Preheat', 'the', 'oven', 'to', '425°F', '.']
# ['Brush', 'the', 'brioche', 'slices', 'with', 'the', 'melted', 'butter', ',', 'and', 'toast', 'them', 'on', 'both', 'sides', 'in', 'the', 'oven', 'until', 'golden', 'brown', '.']
# ['Combine', 'the', 'cream', 'and', 'milk', 'in', 'a', 'saucepan', ',', 'and', 'heat', 'almost', 'to', 'a', 'boil', '.']
# ['Preheat', 'the', 'oven', 'to', '325°F', '.']
# ['For', 'the', 'Sauce', ':']
# ['Fill', 'a', 'large', 'mixing', 'bowl', 'with', 'ice', 'cubes', 'and', 'set', 'aside', '.']
# ['Combine', 'the', 'egg', 'yolks', 'and', 'sugar', 'in', 'another', 'mixing', 'bowl', ',', 'and', 'beat', 'until', 'well', 'blended', '.']
# ['Punch', 'down', 'the', 'dough', '.', 'Cover', 'and', 'refrigerate', 'until', 'doubled', 'in', 'bulk', ',', 'overnight', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.']
# ['To', 'Make', 'the', 'Brine', ':']
# ['To', 'Make', 'the', 'Kraut', ':']
# ['Preheat', 'oven', 'to', '400°F', '(', '200°C', ')']
# ['Variation', ':']
# ['For', 'a', 'savory', 'twist', ',', 'add', '1', 'tbsp', '(', '15', 'mL', ')', 'finely', 'chopped', 'onion', 'in', 'Step', '2', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.']
# ['In', 'a', 'large', 'bowl', ',', 'mix', 'the', 'noodles', 'with', 'the', 'beaten', 'eggs', 'and', '2', 'tablespoons', 'of', 'the', 'sugar', '.', 'Set', 'aside', '.']
# ['Cool', 'slightly', 'and', 'serve']
# ['Have', 'ready', 'five', 'hot', ',', 'sterilized', ',', '1qt', '(', '1', 'liter', ')', 'glass', 'canning', 'jars', 'and', 'lids', '.']
# ['Wipe', 'the', 'jars', 'clean', '.', 'Store', 'in', 'a', 'cool', 'dark', 'place', 'for', 'at', 'least', 'a', 'few', 'weeks', 'before', 'opening', '.']
# ['Bake', '45', 'minutes', ',', 'or', 'until', 'the', 'fruit', 'is', 'tender', 'and', 'the', 'crust', 'is', 'golden', 'brown', '.', 'Brush', 'with', 'the', 'preserves', '.', 'Serve', 'warm', '.']
# ['Basic', 'Risotto']
# ['Apple', 'and', 'Walnut', 'Risotto', ':']
# ['Form', 'the', 'dough', 'into', 'a', 'ball', ',', 'then', 'flatten', 'into', 'a', 'round', 'disk', '.', 'Wrap', 'in', 'plastic', 'wrap', 'and', 'refrigerate', 'for', 'at', 'least', '1', 'hour', '.']
# ['Butter', 'both', 'sides', 'of', 'the', 'brioche', 'slices', '.']
# ['Grill', 'the', 'apple', 'and', 'brioche', 'slices', 'on', 'the', 'plancha', 'for', '2', 'to', '3', 'minutes', 'per', 'side', '.']
# ['At', 'the', 'same', 'time', ',', 'heat', 'honey', 'and', 'lemon', 'juice', 'in', 'a', 'small', 'pot', 'over', 'low', 'heat', '.']
# ['Put', 'brioche', 'slices', 'back', 'together', ',', 'alternating', 'each', 'slice', 'with', 'a', 'slice', 'of', 'apple', '.']
# ['Place', 'apple', 'brioches', 'on', 'dessert', 'plates', 'and', 'sprinkle', 'with', 'lemon', 'honey', '.', 'Serve', 'hot', '.']
# ['3']
# ['Preheat', 'the', 'oven', 'to', '350°F', '(', '180°C', ')', '.', 'Melt', 'the', 'butter', 'in', 'a', 'frying', 'pan', '.', 'Add', 'the', 'bread', 'crumbs', 'and', 'mix', 'well', '.']
# ['Place', 'an', 'oven', 'rack', 'in', 'position', 'C', '(', 'second', 'position', 'from', 'the', 'top', ')', 'and', 'preheat', 'the', 'oven', 'to', '275°F', '.']
# ['Prepare', 'the', 'Bundt', 'pan', '(', 'see', 'Notes', ')', 'and', 'set', 'aside', '.']
# ['Assemble', 'the', 'ingredients', 'via', 'the', 'Creaming', 'Method', ',', 'folding', 'in', 'the', 'apples', 'and', 'pecans', 'last', '.']
# ['The', 'Creaming', 'Method', ':']
# ['Combine', 'all', 'Dry', 'Goods', '(', 'except', 'sugar', ')', 'by', 'pulsing', 'in', 'food', 'processor', '.']
# ['In', 'a', 'small', 'bowl', ',', 'beat', 'eggs', 'together', 'along', 'with', 'any', 'extracts', '.']
# ['Reduce', 'the', 'speed', 'to', '“', 'stir', '”', 'and', 'add', 'the', 'eggs', 'very', 'slowly', ',', 'stopping', 'to', 'scrape', 'down', 'the', 'sides', 'of', 'the', 'bowl', 'as', 'necessary', '.']
# ['Stir', 'in', 'any', 'bits', 'and/or', 'pieces', '(', 'chocolate', 'chips', ',', 'nuts', ',', 'etc', '.', ')', '.']
# ['Pour', 'the', 'batter', 'into', 'the', 'Bundt', 'pan', 'and', 'bake', 'until', 'the', 'internal', 'temperature', 'reaches', '212°F', ',', 'about', '1', 'hour', 'and', '45', 'minutes', '.']
# ['Cool', 'in', 'pan', 'for', '15', 'minutes', ',', 'then', 'remove', 'to', 'rack', 'to', 'cool', 'completely', '.']
# ['Wrapped', 'tightly', ',', 'this', 'will', 'keep', 'for', '5', 'days', '.']
# ['Preheat', 'the', 'oven', 'to', '350°', 'F', '.']
# ['Preheat', 'the', 'oven', 'to', '350°', 'F', '.']
# ['Serve', 'warm', 'with', 'heavy', 'cream', 'or', 'whipped', 'cream', '.']
# ['Preheat', 'oven', 'to', '425', 'degrees', '.']
# ['If', 'you', 'haven', '’', 't', 'already', ',', 'prepare', 'the', 'pastry', 'and', 'refrigerate', 'it', 'until', 'firm', 'enough', 'to', 'roll', ',', '1½', 'to', '2', 'hours', '.']
# ['Transfer', 'the', 'pie', 'to', 'a', 'cooling', 'rack', 'and', 'let', 'cool', 'for', 'at', 'least', '1', 'hour', 'before', 'slicing', '.']
# ['Proceed', 'with', 'brining', 'the', 'turkey', '.']
# ['Variations', ':']
# ['Heat', 'the', 'oven', 'to', '350°F', '.', 'Spray', 'the', 'bottom', 'and', 'sides', 'of', 'a', '13x9x2-inch', 'baking', 'dish', 'or', 'spray', 'with', 'nonstick', 'cooking', 'spray', '.']
# ['To', 'make', 'the', 'filling', ':']
# ['To', 'make', 'the', 'topping', ':']
# ['In', 'a', 'large', 'bowl', ',', 'toss', 'the', 'apples', 'with', 'the', 'vanilla', 'agave', '.']
# ['Spread', 'the', 'apples', 'in', 'a', 'shallow', 'pan', 'and', 'place', 'it', 'in', 'the', 'dehydrator', '.', 'Dehydrate', 'for', 'about', '4', 'hours', ',', 'stirring', 'once', 'or', 'twice', '.']
# ['In', 'a', 'bowl', ',', 'mix', 'together', 'the', 'blended', 'apples', 'and', 'the', 'apple', 'pieces', '.']
# ['Divide', 'the', 'filling', 'among', 'individual', 'ramekins', ',', 'or', 'place', 'it', 'in', 'a', 'shallow', 'baking', 'dish', '.', 'Top', 'the', 'filling', 'with', 'the', 'crisp', '.']
# ['Before', 'serving', ',', 'place', 'the', 'apple', 'crisp', 'in', 'the', 'dehydrator', 'for', 'about', '1', 'to', '2', 'hours', 'to', 'warm', 'it', 'through', '.']
# ['Just', 'before', 'serving', ',', 'drizzle', 'with', 'the', 'vanilla', 'agave', '.']
# ['Preheat', 'oven', 'to', '350°F', '(', '180°C', ')', '.']
# ['Prepare', 'the', 'cake', ':', 'In', 'another', 'bowl', ',', 'combine', 'flour', ',', 'baking', 'powder', 'and', 'baking', 'soda', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.', 'Butter', 'and', 'flour', 'four', 'or', 'eight', '4-ounce', 'ramekins', 'and', 'place', 'them', 'on', 'a', 'sheet', 'pan', '.']
# ['Add', 'the', 'brandy', 'and', 'continue', 'to', 'cook', 'until', 'the', 'liquid', 'has', 'reduced', 'and', 'is', 'syrupy', ',', 'about', '2', 'minutes', '.', 'Remove', 'from', 'the', 'heat', '.']
# ['To', 'finish', 'the', 'fritters', ':']
# ['STOVETOP', 'METHOD', ':', 'Heat', 'a', 'large', 'nonstick', 'skillet', 'over', 'medium-high', 'heat', 'for', '2', 'minutes', '.']
# ['In', 'a', 'large', ',', 'heavy', 'pot', ',', 'heat', '2', 'to', '3', 'inches', 'of', 'vegetable', 'oil', 'until', 'a', 'candy', 'thermometer', 'inserted', 'in', 'the', 'oil', 'reaches', '375°F', '.']
# ['Preheat', 'oven', 'to', '425°F', '.', 'In', 'a', 'large', 'bowl', ',', 'combine', 'the', 'apples', ',', 'lemon', 'juice', ',', 'flour', ',', 'sugar', ',', 'and', 'cinnamon', ';', 'set', 'aside', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Preheat', 'the', 'oven', 'to', '425°']
# ['Prepare', 'the', 'pie', 'dough', 'and', 'line', 'a', '10-inch', 'deep', 'dish', 'pie', 'pan', 'with', 'half', 'the', 'dough', '.']
# ['Peel', 'and', 'core', 'the', 'apples', 'and', 'slice', 'into', 'eighths', '.']
# ['In', 'a', 'bowl', ',', 'toss', 'the', 'apples', 'with', 'the', 'lemon', 'juice', ',', 'sugar', 'and', 'cinnamon', '.', 'Stir', 'in', 'the', 'tapioca', '.']
# ['Turn', 'the', 'filling', 'into', 'the', 'pie', 'pan', 'and', 'dot', 'with', 'butter', '.']
# ['Brush', 'the', 'crust', 'evenly', 'with', 'the', 'egg', 'wash', '.']
# ['Cut', 'vents', 'in', 'the', 'top', 'crust', 'by', 'inserting', 'a', 'paring', 'knife', '¼', 'inch', 'through', 'the', 'dough', '.']
# ['Bake', 'in', 'the', 'center', 'of', 'the', 'oven', 'for', '20', 'minutes', '.']
# ['Reduce', 'the', 'heat', 'to', '350°', 'and', 'continue', 'baking', 'for', '45', 'minutes', 'more', '.']
# ['Cool', 'for', '1', 'hour', 'before', 'serving', '.']
# ['Serve', 'with', 'cheddar', 'cheese', '.']
# ['Bake', 'for', '40', 'to', '45', 'minutes', ',', 'or', 'until', 'the', 'crust', 'is', 'golden', 'brown', '.', 'Serve', 'warm', 'or', 'at', 'room', 'temperature', ',', 'cut', 'into', 'wedges', '.']
# ['Preheat', 'oven', 'to', '375°F', '(', '190°C', ')']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.']
# ['Distribute', 'the', 'apple', 'sauté', 'over', 'the', 'batter', ',', 'then', 'sprinkle', 'the', 'streusel', 'topping', 'over', 'that', '.']
# ['Bake', 'for', '40', 'to', '50', 'minutes', ',', 'until', 'a', 'skewer', 'inserted', 'into', 'the', 'center', 'of', 'the', 'cake', 'comes', 'out', 'clean', '.', 'Cool', 'on', 'a', 'rack', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.', 'Butter', 'and', 'flour', 'a', '10-inch', 'tube', 'pan', '.']
# ['Place', 'the', 'nuts', 'on', 'a', 'rimmed', 'baking', 'sheet', 'and', 'bake', 'for', '8', 'to', '10', 'minutes', ',', 'or', 'until', 'lightly', 'toasted', ';', 'let', 'cool', '.']
# ['Wash', 'and', 'cut', 'Granny', 'Smith', 'apple', 'into', 'small', 'pieces', 'and', 'place', 'in', 'a', 'small', 'bowl', '.', 'Add', 'lemon', 'juice', 'and', 'toss', '.', 'Set', 'aside', '.']
# ['To', 'make', 'the', 'dressing', ':', 'In', 'a', 'jar', 'with', 'a', 'lid', 'combine', 'all', 'ingredients', '.', 'Shake', 'dressing', 'and', 'pour', 'over', 'the', 'salad', '.']
# ['Let', 'cool', 'slightly', '.', 'Rub', 'through', 'a', 'sieve', 'to', 'make', 'a', 'smooth', 'purèe', '.']
# ['Lightly', 'butter', 'shallow', 'a', 'microwave-safe', 'dish', '.']
# ['Transfer', 'the', 'apples', 'to', 'a', 'serving', 'dish', 'and', 'sprinkle', 'with', 'the', 'remaining', 'lavender', 'flowers', '.']
# ['Remove', 'from', 'the', 'heat', ',', 'Using', 'a', 'fork', ',', 'beat', 'in', 'the', 'butter', '.', 'Serve', 'hot', 'or', 'at', 'room', 'temperature', '.']
# ['Beat', 'the', 'apples', 'into', 'a', 'puree', 'with', 'a', 'fork', 'or', 'whisk', '.']
# ['Toss', 'warm', 'donuts', 'with', 'Autumn', 'Spiced', 'Sugar', ',', 'if', 'using', ',', 'or', 'let', 'cool', 'completely', 'prior', 'to', 'icing', '.']
# ['Finishing', 'suggestions']
# ['Icings', ':', 'Autumn', 'Spiced', 'Sugar']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.', 'Grease', '10', 'regular', 'muffin', 'cups', 'or', 'line', 'them', 'with', 'paper', 'liners', '.']
# ['Add', 'the', 'dry', 'ingredients', 'to', 'the', 'liquid', ',', 'and', 'stir', 'with', 'a', 'woodern', 'spoon', 'until', 'just', 'combined', '.', 'Stir', 'in', 'the', 'chopped', 'pecans', '.']
# ['Cool', 'the', 'muffins', 'in', 'the', 'pan', 'on', 'a', 'wire', 'rack', 'for', '15', 'minutes', '.', 'Then', 'unmold', 'them', 'onto', 'a', 'rack', 'to', 'cool', 'completely', '.']
# ['Prepare', 'ahead']
# ['The', 'purèe', 'can', 'be', 'refrigerated', 'for', 'up', 'to', '5', 'days', '.']
# ['3', '.', 'Serve', 'warm', 'or', 'cold', ',', 'in', 'individual', 'serving', 'dishes', 'with', 'layered', 'Greek', 'yogurt', ',', 'muesli', ',', 'and', 'pistachio', 'slivers', '.', 'Variation']
# ['Variation']
# ['Preheat', 'oven', 'to', '350°F', '(', '180°C', ')', '.']
# ['In', 'a', 'large', 'bowl', ',', 'combine', 'flour', ',', 'oats', ',', 'brown', 'sugar', ',', 'oat', 'bran', ',', 'wheat', 'bran', 'and', 'baking', 'soda', '.']
# ['Spread', 'apricot', 'mixture', 'over', 'crumbs', 'in', 'the', 'pan', 'and', 'sprinkle', 'evenly', 'with', 'reserved', 'crumb', 'mixture', '.']
# ['Bake', 'for', '35', 'minutes', 'or', 'until', 'golden', 'brown', 'on', 'top', '.', 'Let', 'cool', 'completely', 'in', 'pan', 'on', 'a', 'wire', 'rack', ',', 'then', 'cut', 'into', 'bars', '.']
# ['Variation', ':', 'Replace', 'the', 'apricots', 'with', 'your', 'favorite', 'dried', 'fruit', '.']
# ['Set', 'a', 'rack', 'at', 'the', 'middle', 'level', 'of', 'the', 'oven', 'and', 'preheat', 'to', '350', 'degrees', '.']
# ['Melt', 'butter', 'in', 'a', 'nonstick', 'skillet', 'over', 'medium', 'heat', '.', 'Add', 'the', 'chicken', 'and', 'cook', '2', 'minutes', 'per', 'side', '.']
# ['TO', 'MAKE', 'THE', 'COOKIES', ':']
# ['Combine', 'the', 'hazelnuts', ',', 'nibs', ',', 'flour', ',', 'cinnamon', ',', 'and', 'cocoa', 'powder', 'in', 'a', 'medium', 'bowl', ',', 'and', 'set', 'aside', '.']
# ['Form', 'the', 'dough', 'into', 'a', '7-inch', 'square', ',', 'wrap', 'in', 'plastic', 'wrap', ',', 'and', 'refrigerate', 'for', '30', 'minutes', '.']
# ['TO', 'COAT', 'THE', 'COOKIES', 'IN', 'CHOCOLATE', ':']
# ['Line', 'a', 'baking', 'sheet', 'with', 'parchment', 'paper', '.']
# ['Dip', 'half', 'of', 'each', 'cookie', 'in', 'the', 'chocolate', 'and', 'place', 'on', 'the', 'baking', 'sheet', 'to', 'harden', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.', 'Grease', '12', 'muffin', 'molds', 'with', 'sunflower', 'oil', '.']
# ['Whisk', 'the', 'eggs', 'and', 'sugar', 'together', 'until', 'they', 'double', 'in', 'volume', 'or', 'form', 'a', 'ribbon', 'consistency', '.']
# ['2g', 'saturated', 'fat', ',', '0.12g', 'sodium']
# ['Preheat', 'an', 'oven', 'to', '350°F', '.', 'Using', 'the', '1', 'teaspoon', 'butter', ',', 'grease', 'a', '10-by-15-inch', 'baking', 'pan', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.', 'Butter', 'and', 'flour', 'a', '10-inch', 'Bundt', 'or', 'tube', 'pan', '.']
# ['Baking', 'Preparations', ':', 'Position', 'rack', 'in', 'lower', 'third', 'of', 'the', 'oven', ';', 'preheat', 'oven', 'to', '350°F', '.']
# ['Grate', 'only', 'the', 'colored', 'portion', 'from', 'the', 'lemon', 'and', 'orange', 'rind', 'for', 'their', 'zests', ';', 'set', 'aside', '.']
# ['Place', 'the', 'butter', 'in', 'the', 'bowl', 'of', 'a', 'heavy-duty', 'mixer', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '(', 'conventional', ')', 'or', '335°F', '(', 'convection', ')', '.']
# ['Place', 'the', 'cake', 'on', 'an', 'oven-safe', 'plate', '.']
# ['Heat', 'the', 'preserves', 'in', 'a', 'saucepan', 'over', 'low', 'heat', 'until', 'the', 'preserves', 'liquefy', ',', 'about', '3', 'to', '4', 'minutes', '.']
# ['Brush', 'a', 'light', 'coat', 'of', 'the', 'warm', 'preserve', 'liquid', 'onto', 'the', 'cake', 'with', 'a', 'pastry', 'brush', '.']
# ['Combine', 'the', 'remaining', 'ingredients', 'in', 'a', 'small', 'bowl', 'and', 'lightly', 'brush', 'the', 'mixture', 'onto', 'the', 'preserve-coated', 'cake', '.']
# ['Bake', 'for', '5', 'minutes', 'to', 'seal', 'in', 'the', 'glaze', '.']
# ['Remove', 'the', 'cake', 'from', 'the', 'oven', 'and', 'let', 'it', 'cool', 'to', 'room', 'temperature', 'before', 'serving', '.']
# ['To', 'Make', 'the', 'Rice', 'Pudding', ':']
# ['To', 'Make', 'the', 'Rhubarb', 'Strawberry', 'Compote', ':']
# ['In', 'place', 'of', 'the', 'Rhubarb', 'Strawberry', 'compote', ',', 'top', 'the', 'pudding', 'with', ':']
# ['•', 'A', 'sprinkle', 'of', 'ground', 'cinnamon']
# ['•', 'Several', 'gratings', 'of', 'fresh', 'nutmeg']
# ['•', 'Fresh', 'berries']
# ['•', 'Sliced', 'mango']
# ['•', 'Lingonberry', 'jam']
# ['•', 'Maple', 'syrup']
# ['Whisk', 'Tabasco', ',', 'sour', 'cream', ',', 'yogurt', ',', 'vinegar', ',', 'and', 'mayonnaise', 'together', '.']
# ['Place', 'chicken', 'and', 'beans', 'into', 'a', 'large', 'ensaladera-salad', 'bowl', ';', 'add', 'lettuce', ';', 'mix', 'with', 'dressing', '.']
# ['Top', 'with', 'avocado', 'slices', 'and', 'tortilla', 'strips', '.']
# ['Mexican', 'Red', 'Sauce', ',', 'Green', 'Sauce', ',', 'or', 'Pico', 'De', 'Gallo', 'goes', 'well', 'with', 'this', 'salad', '.']
# ['Drain', 'the', 'beans', 'into', 'a', 'colander', 'and', 'discard', 'the', 'bay', 'leaf', '.']
# ['In', 'a', 'small', 'mixing', 'bowl', ',', 'mix', 'the', 'herbs', 'together', 'and', 'then', 'blend', 'half', 'of', 'them', 'into', 'the', 'beans', '.']
# ['Wrap', 'the', 'log', 'tightly', 'in', 'plastic', 'wrap', 'and', 'chill', 'it', 'again', 'for', '2', 'hours', 'or', 'overnight', '.']
# ['Cut', 'the', 'log', 'into', '½-to', '1-inch-thtck', 'slices', 'and', 'garnish', 'with', 'walnuts', 'and', 'pomegranate', 'seeds', '.']
# ['Meanwhile', ',', 'make', 'the', 'topping', 'in', 'another', 'large', 'bowl', ',', 'combine', 'all', 'the', 'topping', 'ingredients', 'and', 'mix', 'well', '.']
# ['Preheat', 'the', 'oven', 'to', '450°F', '.', 'Lightly', 'oil', 'two', 'large', 'baking', 'sheets', '.']
# ['Preheat', 'the', 'oven', 'to', '450°F', '.']
# ['Serve', 'at', 'room', 'temperature', 'or', 'chilled', ',', 'garnished', 'with', 'parsley', ',', 'crumbled', 'feta', ',', 'and/or', 'olives', '.']
# ['Meanwhile', ',', 'bring', 'the', 'broth', 'to', 'a', 'simmer', 'in', 'a', 'medium', 'saucepan', '.']
# ['Toast', 'the', 'nuts', 'by', 'heating', 'them', 'for', 'a', 'few', 'minutes', 'in', 'a', 'dry', 'frying', 'pan', ',', 'and', 'sprinkle', 'onto', 'the', 'lamb', 'as', 'you', 'serve', 'it', '.']
# ['1', 'Preheat', 'the', 'oven', 'and', 'a', 'nonstick', 'baking', 'tray', 'to', '425°F', '.']
# ['5', 'Drizzle', 'any', 'tomato', 'spice', 'juices', 'over', 'the', 'tart', 'and', 'serve', '.']
# ['When', 'serving', ',', 'gently', 'stir', 'the', 'rice', 'from', 'the', 'bottom', 'with', 'a', 'fork', 'because', 'the', 'seasonings', 'tend', 'to', 'sink', 'to', 'the', 'bottom', '.']
# ['MAKE', 'AHEAD']
# ['Crumble', 'in', 'the', 'saffron', ',', 'then', 'stir', 'in', 'the', 'stock', ',', 'tomato', 'paste', ',', 'and', 'lemon', 'juice', '.', 'Season', 'with', 'salt', 'and', 'pepper', '.']
# ['TO', 'MAKE', 'THE', 'GREEN', 'GODDESS', 'DRESSING', ':']
# ['TO', 'MAKE', 'THE', 'SALAD', ':']
# ['Preheat', 'the', 'grill', 'to', 'medium-high', '(', '350°F', 'to', '400°F', ')', '.']
# ['In', 'a', 'medium', 'bowl', ',', 'coat', 'the', 'asparagus', 'and', 'green', 'onions', 'evenly', 'with', 'the', 'oil', '.']
# ['Once', 'the', 'asparagus', 'and', 'green', 'onions', 'have', 'cooled', ',', 'slice', 'them', 'on', 'the', 'bias', 'into', '1-', 'to', '2-inch', 'lengths', '.']
# ['Arrange', 'the', 'salad', 'on', 'serving', 'plates', ',', 'top', 'with', 'the', 'hard-boiled', 'eggs', ',', 'and', 'season', 'with', 'the', 'black', 'pepper', '.']
# ['Season', 'to', 'taste', 'with', 'salt', 'and', 'pepper', ',', 'then', 'spoon', 'into', 'a', 'serving', 'bowl', ',', 'cover', ',', 'and', 'refrigerate', 'until', 'ready', 'to', 'serve', '.']
# ['For', 'the', 'Dipping', 'Sauce', ':']
# ['Mix', 'all', 'the', 'ingredients', 'in', 'a', 'small', 'bowl', '.', 'Use', 'a', 'small', 'dollop', 'on', 'each', 'fritter', '.', 'Yield', ':', '1', 'cup']
# ['For', 'the', 'Fritters', ':']
# ['Drain', 'on', 'paper', 'towels', 'and', 'serve', 'immediately', '.']
# ['To', 'prepare', 'the', 'Artichokes', ':']
# ['To', 'prepare', 'the', 'Artichokes', ':']
# ['Cut', 'the', 'artichokes', 'in', 'half', 'length', 'wise', ',', 'remove', 'the', 'hairy', 'choke', ',', 'and', 'trim', '1', 'inch', 'of', 'bracts', '(', 'leaves', ')', 'from', 'the', 'top', '.']
# ['To', 'make', 'the', 'sauce', ',', 'combine', 'the', 'tomato', 'sauce', ',', 'lemon', 'juice', ',', 'sugar', ',', 'salt', ',', 'and', '1', 'cup', 'water', '.', 'Mix', 'well', '.']
# ['Variation', 'for', 'Artichoke', 'Hearts', 'with', 'Onion', ',', 'Balsamic', 'Vinegar', ',', 'and', 'Parmesan', 'Cheese']
# ['Dressing', 'Artichoke', 'Hearts', 'with', 'Onion', ',', 'Balsamic', 'Vinegar', ',', 'and', 'Parmesan', 'Cheese', 'Up']
# ['Saucy', 'Accompaniments']
# ['If', 'you', '’', 're', 'going', 'to', 'serve', 'the', 'artichokes', 'hot', ',', 'while', 'they', '’', 're', 'cooking', ',', 'whip', 'up', 'a', 'saucy', 'accompaniment', 'to', 'dip', 'them', 'in', '.']
# ['•', 'Heat', '½', 'cup', 'olive', 'oil', 'until', 'hot', '.', 'Remove', 'it', 'from', 'the', 'heat', 'and', 'stir', 'in', '½', 'cup', 'minced', 'fresh', 'herbs', 'of', 'your', 'choice', '.']
# ['Mix', 'the', 'arugula', ',', 'ham', ',', 'and', 'pear', 'pieces', 'in', 'a', 'large', 'bowl', '.']
# ['Pour', 'the', 'dressing', 'over', 'the', 'arugula', 'mixture', ',', 'then', 'sprinkle', 'the', 'toasted', 'walnut', 'pieces', 'on', 'top', '.']
# ['Whisk', 'together', 'the', 'olive', 'oil', ',', 'lemon', 'juice', ',', 'and', 'salt', 'in', 'a', 'large', 'non-metallic', 'bowl', '.', 'Add', 'the', 'arugula', 'and', 'toss', 'together', '.']
# ['Variation', ':']
# ['Variation', ':']
# ['For', 'the', 'Lemon', 'Vinaigrette', ':']
# ['Repeat', 'the', 'blanching', ',', 'shocking', ',', 'and', 'draining', 'for', 'the', 'haricots', 'verts', ',', 'using', 'a', 'colander', 'to', 'drain', '.']
# ['Variations', ':']
# ['For', 'a', 'main-course', 'salad', ',', 'top', 'each', 'serving', 'with', 'a', 'portion', 'of', 'sautéed', 'or', 'grilled', 'fish', 'or', 'chicken', '.']
# ['Preheat', 'the', 'broiler', '.']
# ['Combine', 'the', 'scallions', ',', 'mint', ',', 'cilantro', ',', 'and', 'lemongrass', 'in', 'a', 'small', 'bowl', '.', 'Mix', 'well', 'and', 'set', 'aside', '.']
# ['In', 'a', 'large', 'bowl', ',', 'combine', 'the', 'chicken', ',', 'vegetables', ',', 'and', 'sesame', 'seeds', '.', 'Toss', 'well', '.']
# ['Using', 'a', 'cleaver', 'or', 'a', 'heavy', 'knife', ',', 'chop', 'the', 'chicken', 'wings', 'at', 'the', 'joints', '.', '(', 'Or', 'ask', 'the', 'butcher', 'to', 'chop', 'them', 'for', 'you', '.', ')']
# ['For', 'each', 'wrap', ',', 'place', 'one-fourth', 'of', 'the', 'chicken', 'mixture', 'on', 'a', 'tortilla', 'and', 'roll', 'up', '.', 'Serve', 'hot', '.']
# ['Separate', 'bok', 'choy', 'leaves', '.', 'Rinse', 'and', 'pat', 'dry', '.']
# ['Pour', 'dressing', 'over', 'salad', 'and', 'toss', '.', 'Allow', 'salad', 'to', 'sit', 'for', '30', 'minutes', 'before', 'serving', '.', 'Garnish', 'with', 'cashews', 'and', 'serve', '.']
# ['To', 'make', 'the', 'dressing', ',', 'shake', 'the', 'vinegar', ',', 'oil', ',', 'cilantro', ',', 'fish', 'sauce', ',', 'chili', 'sauce', ',', 'and', 'garlic', 'in', 'a', 'jar', '.']
# ['10', 'minutes', 'before', 'serving', ',', 'pour', 'the', 'dressing', 'over', 'the', 'cucumber', 'and', 'season', 'with', 'salt', 'and', 'pepper', '.']
# ['Heat', 'the', 'oil', 'in', 'a', '2-quart', 'saucepan', 'or', 'small', 'soup', 'pot', '.', 'Add', 'the', 'onion', 'and', 'garlic', 'and', 'sauté', 'over', 'medium', 'heat', 'until', 'golden', '.']
# ['Add', 'the', 'broth', ',', 'mushrooms', ',', 'and', 'soy', 'sauce', '.', 'Bring', 'to', 'a', 'simmer', ',', 'then', 'cover', 'and', 'simmer', 'gently', 'for', '15', 'minutes', '.']
# ['Preheat', 'the', 'oven', 'to', '250°F', '.', 'Line', 'a', 'rimmed', 'baking', 'sheet', 'with', 'parchment', 'paper', '.']
# ['Variation', ':', 'Pork', 'tenderloin', '(', '1½', 'pounds', ')', 'thinly', 'sliced', 'may', 'be', 'substituted', 'for', 'the', 'chicken', '.']
# ['For', 'the', 'ginger', 'syrup', ':']
# ['To', 'Make', 'the', 'Sliders', ':']
# ['Preheat', 'oven', '450°F', '.', 'Line', 'baking', 'sheet', 'with', 'foil', '.']
# ['To', 'Make', 'the', 'Salsa', ':']
# ['In', 'bowl', ',', 'mix', 'together', 'all', 'ingredients', '.', 'Refrigerate', '.']
# ['To', 'Make', 'the', 'Sauce', ':']
# ['For', 'the', 'Chicken', ':']
# ['Season', 'chicken', 'with', 'all', 'of', 'the', 'above', 'and', 'steam', 'in', 'bamboo', 'basket', 'over', 'pan', 'of', 'simmering', 'water', 'for', 'about', '12', '-', '15']
# ['minutes', '.', 'Then', 'slice', 'thinly', 'and', 'toss', 'in', 'vinaigrette', '.']
# ['For', 'the', 'Vinaigrette', ':']
# ['Combine', 'all', 'of', 'the', 'below', 'in', 'a', 'bowl', 'and', 'whisk', '.']
# ['For', 'the', 'Vegetables', ':']
# ['Variation', ':', 'Replace', 'tofu', 'with', '¾', 'pound', 'cubed', 'skinless', ',', 'boneless', 'chicken', 'breast', 'or', '¾', 'pound', 'cooked', 'medium', 'prawns', '.']
# ['In', 'a', '12-inch', 'skillet', 'over', 'high', 'heat', ',', 'sauté', 'the', 'scallions', 'and', 'onions', 'in', 'the', 'vegetable', 'oil', '.']
# ['First', ',', 'press', 'the', 'tofu', 'for', 'at', 'least', '15', 'minutes', '.']
# ['Preheat', 'the', 'oven', 'to', '350°F', '.', 'Oil', 'a', 'large', 'baking', 'pan', '.']
# ['Mound', 'one', 'quarter', 'of', 'the', 'filling', 'on', 'each', 'mushroom', ',', 'pressing', 'with', 'your', 'fingers', 'to', 'compact', '.']
# ['Bake', 'for', '35', 'to', '40', 'minutes', 'until', 'the', 'mushrooms', 'release', 'juice', 'and', 'the', 'filling', 'is', 'firm', 'and', 'slightly', 'browned', '.']
# ['While', 'the', 'mushrooms', 'bake', ',', 'prepare', 'the', 'Simple', 'Sweet', 'and', 'Sour', 'Sauce', '.']
# ['Combine', 'the', 'ginger', 'and', 'com', 'oil', 'in', 'a', 'small', 'bowl', ',', 'cover', ',', 'and', 'refrigerate', 'overnight', '.', 'Strain', '.']
# ['Prepare', 'the', 'crêpes', '.']
# ['Cook', 'pasta', ',', 'following', 'package', 'instructions', '.']
# ['Steam', 'asparagus', 'for', '5', 'minutes', '.']
# ['In', 'a', 'small', 'bowl', ',', 'stir', 'together', 'the', 'stock', 'and', 'the', 'soy', 'and', 'hoisin', 'sauces', '.', 'Set', 'aside', '.']
# ['Remove', 'and', 'discard', 'the', 'tough', 'muscle', 'from', 'the', 'scallops', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', 'and', 'prepare', 'a', 'steamer', '.']
# ['Basic', 'Risotto', ':']
# ['TO', 'ROAST', 'THE', 'ASPARAGUS', ':', 'Adjust', 'the', 'oven', 'rack', 'to', 'the', 'middle', 'position', ',', 'and', 'preheat', 'the', 'oven', 'to', '450', 'degrees', '.']
# ['Grill', 'the', 'bread', '(', 'see', 'Note', '.', ')']
# ['Rub', 'one', 'side', 'of', 'each', 'slice', 'of', 'bread', 'with', 'the', 'garlic', 'clove', ',', 'and', 'place', 'on', 'a', 'baking', 'sheet', ',', 'garlic', 'side', 'up', '.']
# ['Arrange', 'the', 'asparagus', 'over', 'each', 'slice', 'of', 'bread', 'and', 'place', 'on', 'a', 'baking', 'sheet', '.']
# ['Adjust', 'the', 'oven', 'rack', 'to', 'the', 'upper', 'position', ',', 'and', 'preheat', 'the', 'broiler', '.']
# ['Place', 'the', 'eggs', 'centered', 'over', 'the', 'asparagus', '.', 'Poach', 'the', 'other', '2', 'eggs', 'in', 'the', 'same', 'manner', '.']
# ['Preheat', 'the', 'oven', 'to', '350', '?', 'F', '.']
# ['Serve', 'the', 'tart', 'hot', ',', 'cut', 'into', 'wedges', ',', 'with', 'a', 'green', 'salad', '.']
# ['Preheat', 'oven', 'to', '375°F', '(', '190°C', ')']
# ['Meanwhile', ',', 'in', 'a', 'bowl', ',', 'combine', 'ricotta', ',', 'mozzarella', 'and', 'Parmesan', 'cheeses', ',', 'thyme', 'and', 'oil', '.', 'Add', 'salt', 'and', 'pepper', ',', 'to', 'taste', '.']
# ['Preheat', 'oven', 'or', 'toaster', 'oven', 'to', '400', 'degrees', 'F', '.']
# ['Lay', 'the', 'asparagus', 'spears', 'along', 'the', 'bottom', 'of', 'a', 'glass', 'baking', 'dish', 'or', 'the', 'toaster', 'oven', 'tray', '.', 'It', '’', 's', 'okay', 'if', 'they', 'overlap', '.']
# ['Sprinkle', 'the', 'vinegar', 'and', 'olive', 'oil', 'on', 'top', ',', 'followed', 'by', 'the', 'salt', 'and', 'pepper', '.']
# ['Place', 'in', 'the', 'oven', 'for', 'about', '10', 'minutes', '.']
# ['Place', 'in', 'the', 'oven', 'and', 'bake', 'until', 'the', 'whites', 'are', 'set', 'and', 'yolks', 'are', 'still', 'runny', ',', '8', 'to', '10', 'minutes', '.', 'Eat', 'piping', 'hot', '.']
# ['Divide', 'the', 'asparagus', 'among', 'salad', 'plates', '.', 'Top', 'with', 'the', 'mustard', 'sauce', 'and', 'sprinkle', 'with', 'the', 'red', 'onion', '.', 'Serve', 'immediately', '.']
# ['Variation', ':']
# ['In', 'a', 'medium', 'bowl', ',', 'mix', 'the', 'vinegar', ',', 'oil', ',', 'and', 'soy', 'sauce', '.']
# ['Prepare', 'a', 'medium', 'bowl', 'of', 'ice', 'water', ',', 'and', 'set', 'aside', '.']
# ['To', 'serve', ',', 'divide', 'the', 'asparagus', 'among', '4', 'plates', '.', 'Sprinkle', 'with', 'the', 'pistachios', 'and', 'shredded', 'egg', '.']
# ['VARIATIONS', ':']
# ['RED', 'BELL', 'PEPPER', 'MAYONNAISE']
# ['Yield', ':', '1¾', 'cups']
# ['4', 'red', 'bell', 'peppers', ',', 'charred', ',', 'peeled', ',', 'stemmed', ',', 'seeded', ',', 'and', 'chopped', 'fine']
# ['1', 'cup', 'Basic', 'Mayonnaise']
# ['Salt', 'and', 'pepper', 'to', 'taste']
# ['Combine', 'the', 'peppers', 'with', 'the', 'Basic', 'Mayonnaise', 'and', 'season', 'to', 'taste', 'with', 'salt', 'and', 'pepper', '.']
# ['MUSHROOM', 'MAYONNAISE']
# ['Yield', ':', '2', 'cups']
# ['1', 'pound', 'mushrooms', 'of', 'any', 'variety']
# ['1', 'cup', 'Basic', 'Mayonnaise']
# ['Salt', 'and', 'pepper', 'to', 'taste']
# ['MOREL', 'MAYONNAISE']
# ['Yield', ':', '1½', 'cups']
# ['Regular', 'mushroom', 'mayonnaise', 'is', 'great', 'but', 'dried', 'morels', 'give', 'this', 'mayonnaise', 'a', 'distinctive', 'smoky', 'flavor', '.']
# ['1', 'ounce', 'dried', 'morels', ',', 'soaked', 'in', '½', 'cup', 'water', 'for', '30', 'minutes', 'and', 'moved', 'around', 'every', '5', 'minutes']
# ['1', 'cup', 'Basic', 'Mayonnaise']
# ['salt', 'and', 'pepper', 'to', 'taste']
# ['CAPER', 'AND', 'HERB', 'MAYONNAISE']
# ['Yield', ':', '1¾', 'cups']
# ['1', 'cup', 'Basic', 'Mayonnaise']
# ['1', 'tablespoon', 'Dijon', 'mustard']
# ['4', 'tablespoons', 'capers', ',', 'drained', 'and', 'chopped', 'coarse', 'leaves', 'from', '15', 'sprigs', 'fresh', 'tarragon', ',', 'chopped']
# ['1', 'small', 'bunch', 'parsley', ',', 'large', 'stems', 'removed', ',', 'leaves', 'and', 'small', 'stems', 'chopped']
# ['salt', 'and', 'pepper', 'to', 'taste']
# ['Combine', 'the', 'Basic', 'Mayonnaise', 'with', 'the', 'other', 'ingredients', '.', 'Season', 'with', 'salt', 'and', 'pepper', 'to', 'taste', '.']
# ['Variation']
# ['For', 'the', 'Basic', 'Bruschetta', ':']
# ['For', 'the', 'Basic', 'Bruschetta', ':']
# ['For', 'the', 'Aubergine', 'and', 'Mint', ':']
# ['Cook', ',', 'stirring', 'constantly', ',', 'until', 'the', 'fondue', 'just', 'comes', 'to', 'a', 'simmer', '.', 'Stir', 'in', 'the', 'kirsch', ',', 'and', 'season', 'with', 'pepper', '.']
# ['To', 'serve', ',', 'transfer', 'the', 'pot', 'to', 'its', 'stand', 'on', 'the', 'table', '.', 'Spear', 'the', 'bread', 'cubes', 'onto', 'fondue', 'forks', 'and', 'dunk', 'into', 'the', 'cheese', '.']
# ['Toss', 'warm', 'donuts', 'into', 'sugar', 'to', 'coat', 'completely', '.']
# ['Preheat', 'the', 'oven', 'to', '350°', 'F', '.']
# ...
# ['Serve', 'with', 'my', 'ferrari', 'potatoes', 'and', 'spinach', 'with', 'black', 'pepper', ',', 'garlic', ',', 'and', 'lemon', '.']
# ['Serve', 'chicken', 'and', 'roasted', 'veggies', 'with', 'warm', 'chocolate', 'sauce', 'on', 'the', 'side', 'for', 'dipping', '.']
# ['Put', 'the', 'flours', 'into', 'a', 'mixing', 'bowl', 'and', 'add', 'the', 'baking', 'powder', ',', 'baking', 'soda', ',', 'salt', ',', 'and', 'sugar', '.', 'Stir', 'with', 'a', 'fork', 'to', 'blend', '.']
# ['Bake', 'in', 'a', 'hot', 'waffle', 'iron', 'until', 'crisp', 'and', 'golden', '.', 'Serve', 'hot', '.']
# ['Variations', ':']
# ['Raisin', 'and', 'lemon', 'pancakes', ':']
# ['Savory', 'pancakes', ':']
# ['Hand', 'Method']
# ['Stand', 'Mixer', 'Method']
# ['Food', 'Processor', 'Method']
# ['Transfer', 'to', 'a', 'plate', 'lightly', 'dusted', 'with', 'flour', ',', 'cover', 'with', 'plastic', 'wrap', 'and', 'let', 'rest', 'for', '1', 'hour', '.']
# ['Rolling', 'Fresh', 'Pasta']
# ['Tip']
# ['Using', 'a', 'Pastry', 'Board']
# ['Hand', 'Method']
# ['Machine', 'Method']
# ['Divide', 'the', 'pasta', 'among', 'warm', 'bowls', 'and', 'serve', 'immediately', '.', 'Pass', 'the', 'additional', 'cheese', 'at', 'the', 'table', '.']
# ['Whisk', 'the', 'flour', 'and', 'salt', 'together', 'in', 'a', 'large', 'mixing', 'bowl', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Preheat', 'the', 'oven', 'to', '350', 'degrees', '.']
# ['Variation', ':']
# ['Add', '¼', 'cup', 'minced', 'dried', 'tomato', ',', 'reconstituted', 'or', 'oil-cured', ',', 'as', 'preferred', '.']
# ['In', 'a', '2-cup', 'liquid', 'measure', ',', 'combine', 'the', 'soymilk', 'and', 'lemon', 'juice', ';', 'set', 'aside', '.', '(', 'The', 'mixture', 'will', 'curdle', '.', ')']
# ['Other', 'Ideas', ':']
# ['Add', '2', 'tablespoons', 'of', 'shelled', ',', 'unsalted', 'sunflower', 'seeds', 'to', 'the', 'batter', '.']
# ['Whisk', 'the', 'eggs', 'into', 'the', 'cooled', 'cocoa', 'syrup', '.']
# ['Serve', 'with', 'butter', 'and', 'warm', 'maple', 'syrup', '.']
# ['Ladle', 'into', 'heated', 'bowls', 'and', 'garnish', 'with', 'chives', '.']
# ['Stir', 'in', 'the', 'potato', 'flakes', 'and', 'parsley', 'and', 'cook', 'on', 'high', 'for', '10', 'minutes']
# ['Clean', 'the', 'mushrooms', 'with', 'a', 'mushroom', 'brush', 'or', 'paper', 'toweling', '.', 'Cut', 'off', 'the', 'stems', 'and', 'reserve', '.', 'Slice', 'the', 'mushroom', 'caps', '.']
# ['In', 'a', 'large', 'bowl', ',', 'whisk', 'the', 'eggs', ',', 'then', 'gradually', 'whisk', 'in', 'the', 'milk', '.', 'Slowly', 'whisk', 'in', 'the', 'hot', 'stock', 'mixture', 'and', 'set', 'aside', '.']
# ['Use', 'the', 'remaining', '1', 'tablespoon', 'butter', 'to', 'lightly', 'grease', 'an', '8½', 'x', '14½-inch', 'loaf', 'pan', '.']
# ['For', 'the', 'Bruschetta']
# ['Preheat', 'a', 'charcoal', 'or', 'gas', 'grill', 'to', 'hot', '.']
# ['Place', 'the', 'bruschetta', 'on', 'serving', 'plates', '.', 'Divide', 'the', 'topping', 'evenly', 'among', 'them', '.']
# ['For', 'the', 'Warm', 'Duxelles', 'and', 'Potato', 'Topping', ':']
# ['For', 'the', 'Grilled', 'Portobello', 'Topping', ':']
# ['Cut', 'the', 'portobello', 'caps', 'into', '¼-inch', 'dice', '.', 'Mix', 'with', 'the', 'herbs', ',', 'spoon', 'onto', 'the', 'bruschetta', ',', 'and', 'serve', '.']
# ['Add', 'the', 'mushrooms', 'and', 'sauté', '5', 'minutes', '.']
# ['To', 'serve', ',', 'remove', 'the', 'thyme', 'stems', 'and', 'bay', 'leaves', 'and', 'ladle', 'the', 'soup', 'into', 'bowls', '.']
# ['Prepare', 'the', 'crêpes', '.']
# ['Prepare', 'the', 'vinaigrette', '.']
# ['Arrange', 'one', 'rack', 'in', 'the', 'center', 'of', 'the', 'oven', 'and', 'one', '6', 'inches', 'from', 'the', 'top', ',', 'Heat', 'the', 'oven', 'to', '375°F', '.']
# ['Remove', 'the', 'pan', 'from', 'the', 'oven', 'and', 'turn', 'on', 'the', 'broiler', '.']
# ['In', 'a', 'small', 'bowl', ',', 'mix', 'the', 'dried', 'cherries', 'and', 'port', ',', 'and', 'let', 'stand', 'while', 'preparing', 'the', 'stuffing', '.']
# ['Mix', 'the', 'spices', 'thoroughly', 'in', 'a', 'bowl', '.', 'Store', 'covered', 'in', 'a', 'cool', ',', 'dark', 'pantry', '.']
# ['For', 'the', 'Shallots', ':']
# ['For', 'the', 'Salad', ':']
# ['In', 'a', 'small', 'bowl', ',', 'whisk', 'together', 'the', 'vinegar', ',', 'mustard', ',', 'salt', ',', 'pepper', ',', 'and', 'olive', 'oil', '.']
# ['Pour', 'the', 'sauce', 'over', 'the', 'chicken', 'on', 'the', 'plate', ',', 'top', 'with', 'the', 'toasted', 'almonds', ',', 'and', 'eat', '.']
# ['Ladle', 'the', 'hot', 'stew', 'into', 'bowls', ',', 'garnish', 'with', 'scallions', ',', 'and', 'serve', '.']
# ['Variations', ':']
# ['Place', 'a', 'rack', 'in', 'the', 'middle', 'of', 'the', 'oven', 'and', 'preheat', 'to', '450', 'degrees', 'F', '.']
# ['Variations', ':']
# ['Peel', 'and', 'core', 'a', 'tart', 'apple', 'instead', 'of', 'the', 'pear', '.']
# ['Substitute', 'goat', 'cheese', 'or', 'a', 'hard', 'grating', 'cheese', ',', 'like', 'Parmesan', ',', 'for', 'the', 'blue', 'cheese', '.']
# ['Substitute', 'dried', 'cherries', 'for', 'the', 'cranberries', '.']
# ['Substitute', 'coarsely', 'chopped', 'walnuts', ',', 'pecans', ',', 'pistachios', ',', 'or', 'your', 'favorite', 'nuts', 'for', 'the', 'almonds', '.']
# ['The', 'first', 'day']
# ['The', 'second', 'day']
# ['The', 'third', 'day']
# ['Sterilize', '5', 'to', '6', 'pint', 'canning', 'jars', 'according', 'to', 'the', 'manufacturer', '’', 's', 'directions', '.']
# ['Continue', 'to', 'simmer', 'until', 'the', 'bok', 'choy', 'is', 'just', 'crisp', 'and', 'the', 'wontons', 'are', 'just', 'heated', 'through', ',', 'about', '3', 'to', '4', 'minutes', '.']
# ['Ladle', 'into', 'heated', 'bowls', 'and', 'sprinkle', 'with', 'the', 'scallions', '.']
# ['Divide', 'the', 'filling', 'among', 'six', '5-', 'to', '6-ounce', 'ramekins', 'or', 'custard', 'dishes', 'about', '3½', '×', '2', 'inches', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['The', 'sauce', 'will', 'keep', 'for', '1', 'year', 'covered', 'in', 'brown', 'paper', 'in', 'a', 'cool', ',', 'dark', 'spot', 'in', 'your', 'pantry', '.']
# ['Serve', 'in', 'mugs', 'or', 'bowls', 'with', 'cheese', 'and', 'sour', 'cream', 'on', 'top', '.']
# ['For', 'the', 'Basic', 'Risotto', ':']
# ['Mound', 'the', 'rice', 'on', 'a', 'platter', ',', 'garnish', 'with', 'the', 'onion', 'rings', ',', 'and', 'serve', '.']
# ['Put', 'the', 'roasted', 'lentils', ',', '2', 'cups', 'of', 'water', ',', 'turmeric', ',', 'cayenne', 'pepper', 'powder', ',', 'and', 'salt', 'in', 'a', 'pot', 'and', 'cook', 'for', '10', 'minutes', '.']
# ['Pour', 'split', 'peas', 'into', 'medium', 'bowl', ',', 'cover', 'with', 'cold', 'water', ',', 'and', 'soak', 'overnight', '.']
# ['Drain', 'peas', 'in', 'colander', ',', 'rinse', ',', 'put', 'into', 'a', 'soup', 'pot', ',', 'cover', 'with', '6', 'cups', '(', '1½', 'L', ')', 'water', ',', 'and', 'bring', 'to', 'a', 'boil', 'over', 'high', 'heat', '.']
# ['Stir', 'in', 'onion', ',', 'mint', ',', 'and', 'olive', 'oil', ';', 'reduce', 'heat', 'to', 'low', '.']
# ['Cover', 'and', 'cook', '1', 'hour', 'or', 'until', 'peas', 'are', 'tender', 'when', 'crushed', 'against', 'the', 'side', 'of', 'pot', '.']
# ['Blend', 'soup', 'in', 'an', 'electric', 'blender', 'or', 'food', 'processor', 'until', 'smooth', '.']
# ['Return', 'to', 'soup', 'pot', 'and', 'heat', 'over', 'medium', 'heat', 'until', 'thickened', '.']
# ['Ladle', 'into', 'soup', 'bowls', 'and', 'stir', 'in', 'a', 'generous', 'spoonful', 'of', 'spiced', 'butter', '.']
# ['Once', 'the', 'tuna', 'has', 'chilled', 'completely', ',', 'cut', 'the', 'steaks', 'into', '1½–2-inch', 'cubes', '.']
# ['An', 'Easy', 'Tartufo', 'Loaf']
# ['Spoon', 'the', 'spinach', 'sauce', 'over', 'the', 'chicken', 'pieces', ',', 'and', 'serve', '.']
# ['Baking', 'Preparations', ':', 'Position', 'rack', 'in', 'lower', 'third', 'of', 'oven', ';', 'preheat', 'oven', 'to', '350°F', '.']
# ['Crack', 'the', 'eggs', 'into', 'a', 'small', 'bowl', ',', 'and', 'whisk', 'just', 'to', 'combine', 'the', 'yolks', 'and', 'the', 'whites', '.']
# ['Pour', 'the', 'yogurt', 'into', 'a', 'liquid', 'cup', 'measure', '.']
# ['Grate', 'only', 'the', 'yellow', 'part', 'of', 'the', 'lemon', 'for', 'the', 'zest', '.']
# ['Place', 'the', 'butter', 'in', 'the', 'bowl', 'of', 'a', 'heavy-duty', 'mixer', '.']
# ['Cover', 'the', 'cake', 'with', 'a', 'cooling', 'rack', ',', 'invert', 'it', 'onto', 'the', 'rack', ',', 'and', 'carefully', 'lift', 'the', 'pan', 'to', 'remove', '.', 'Cool', 'completely', '.']
# ['Toss', 'the', 'whole', 'almonds', 'with', 'the', 'remaining', 'glaze', ',', 'and', 'place', 'each', 'one', 'strategically', 'on', 'the', 'cake', 'to', 'decorate', 'it', '.']
# ['Fold', 'the', 'cucumbers', 'into', 'the', 'mixture', ',', 'cover', ',', 'and', 'chill', 'until', 'serving', 'time', ';', 'it', 'will', 'keep', ',', 'refrigerated', ',', 'for', 'up', 'to', '2', 'days', '.']
# ['Combine', 'all', 'of', 'the', 'ingredients', 'except', 'the', 'chives', 'in', 'a', 'blender', 'and', 'purée', 'until', 'smooth', '.', 'Stir', 'in', 'the', 'chives', '.']
# ['Stir', 'in', 'half', 'of', 'the', 'remaining', 'milk', '.', 'Change', 'to', 'a', 'whisk', ',', 'and', 'whisk', 'in', 'the', 'remaining', 'milk', '.', 'Let', 'stand', 'for', '30', 'minutes', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', '.']
# ['Toss', 'the', 'herbs', 'in', 'a', 'small', 'bowl', 'with', 'salt', ',', 'pepper', ',', 'a', 'drizzle', 'of', 'super-good', 'olive', 'oil', ',', 'and', 'a', 'squeeze', 'of', 'lemon', 'juice', '.']
# ['To', 'serve', 'individual', 'portions', ',', 'cut', 'six', 'wedges', 'from', 'the', 'tart', 'and', 'garnish', 'each', 'one', 'with', 'a', 'little', 'herb', 'salad', '.']
# ['In', 'a', 'small', 'bowl', ',', 'combine', 'the', 'lime', 'juice', ',', 'fish', 'sauce', 'or', 'salt', ',', 'sugar', ',', 'chile', 'sauce', ',', 'and', '1', 'tablespoon', 'water', '.']
# ['To', 'Serve', ':']
# ['Serve', 'with', 'a', 'tossed', 'salad', '.']
# ['Bring', 'your', 'smoker', 'to', 'its', 'appropriate', 'cooking', 'temperature', '.']
# ['Coat', 'the', 'chorizo', 'with', 'oil', '.', 'Sprinkle', 'it', 'with', 'the', 'garlic', 'powder', 'and', 'let', 'it', 'sit', 'at', 'room', 'temperature', 'for', '20', 'minutes', '.']
# ['Grease', 'a', 'shallow', 'baking', 'dish', ',', 'preferably', 'about', '13', 'inches', 'long', 'and', '7', 'to', '9', 'inches', 'wide', '.']
# ['When', 'the', 'beans', 'are', 'ready', ',', 'stir', 'the', 'mint', 'into', 'them', '.']
# ['Garnish', 'with', 'limes', 'and', 'mint', ',', 'if', 'you', 'wish', ',', 'and', 'serve', 'immediately', '.']
# ['Serve', 'immediately', ',', 'preferably', 'with', 'berries', 'or', 'mixed', 'fresh', 'fruits', '.']
# ['Bring', 'a', 'large', 'saucepan', 'of', 'water', 'to', 'a', 'boil', ',', 'then', 'lower', 'the', 'heat', 'to', 'simmer', '.']
# ['Store', 'in', 'an', 'airtight', 'container', 'for', 'up', 'to', '1', 'month', '.']
# ['Preheat', 'the', 'oven', 'to', '325', 'degrees', 'F', 'and', 'line', '2', 'baking', 'sheets', 'with', 'parchment', 'paper', '.']
# ['Add', 'the', 'eggs', ',', 'one', 'at', 'a', 'time', ',', 'to', 'the', 'flour', 'mixture', ',', 'beating', 'well', 'with', 'a', 'hand-held', 'mixer', 'until', 'incorporated', '.']
# ['Using', 'a', 'vegetable', 'peeler', ',', 'remove', 'the', 'zest', 'from', '4', 'of', 'the', 'lemons', 'in', 'strips', '.', 'Scrape', 'away', 'any', 'white', 'pith', '.']
# ['Pour', 'the', 'syrup', 'into', 'a', 'shallow', ',', 'freezerproof', 'nonreactive', 'bowl', '.', 'Stir', 'in', 'the', 'lemon', 'zest', 'strips', 'and', 'let', 'cool', 'completely', '.']
# ['Meanwhile', ',', 'place', 'the', 'remaining', 'ingredients', 'in', 'a', 'small', 'bowl', 'and', 'stir', 'well', 'to', 'combine', '.']
# ['Preheat', 'the', 'oven', 'to', '400°F', 'and', 'put', 'in', 'a', 'baking', 'sheet', '.']
# ['Preheat', 'broiler', '.']
# ['Sprinkle', 'with', 'paprika', 'and', 'serve', 'warm', '.', 'The', 'topping', 'mixture', 'may', 'be', 'made', 'a', 'day', 'ahead', 'and', 'refrigerated', 'until', 'ready', 'to', 'use', '.']
# ['Variations', ':']
# ['1/4', 'cup', 'chopped', 'kalamata', 'olives', 'can', 'be', 'added', 'to', 'this', 'mixture', '.']
# ['Chopped', 'red', 'pepper', 'can', 'be', 'used', 'as', 'a', 'garnish', 'for', 'a', 'more', 'colorful', 'combination', 'once', 'they', 'are', 'removed', 'from', 'the', 'broiler', '.']
# ['To', 'add', 'spice', ',', 'omit', 'basil', 'and', 'use', 'chopped', 'jalapeño', 'and', '1/2', 'cup', 'chopped', 'onion', '.']
# ['Melba', 'toast', 'rounds', 'can', 'be', 'substituted', 'for', 'zucchini', '.']
# ['To', 'extract', 'water', 'from', 'the', 'zucchini', ',', 'place', 'it', 'in', 'a', 'colander', 'and', 'press', 'it', 'down', 'against', 'the', 'perforated', 'surface', '.']
# ['Combine', 'the', 'zucchini', ',', 'eggs', ',', 'onions', ',', 'allspice', ',', 'salt', ',', 'and', 'cinnamon', ',', 'if', 'desired', ',', 'in', 'a', 'medium', 'mixing', 'bowl', '.', 'Mix', 'well', '.']
# ['Chill', 'for', '2', 'hours', '.']
# ['The', 'hummus', 'will', 'keep', 'for', '3', 'days', 'in', 'the', 'refrigerator', '.']
# ['Dry', 'off', 'the', 'bowl', 'and', 'put', 'the', 'zucchini', 'back', 'in', 'it', '.']
# ['Sift', 'the', 'chickpea', 'flour', 'over', 'this', 'vegetable', 'mixture', '.', 'Mix', 'well', 'and', 'form', '16', 'neat', 'balls', '.']
# ['When', 'hot', ',', 'put', 'in', '5', 'to', '6', 'of', 'the', 'balls', ',', 'or', 'as', 'many', 'as', 'the', 'utensil', 'will', 'hold', 'easily', 'in', 'one', 'layer', '.']
# ['These', '“', 'meatballs', '”', 'turn', 'very', 'soft', 'when', 'cooked', 'in', 'the', 'sauce', ',', 'so', 'handle', 'them', 'gently', 'and', 'serve', 'immediately', '.']
# ['Preheat', 'the', 'oven', 'to', '375°F', '.']
# ['Serve', 'at', 'room', 'temperature', 'with', 'an', 'accompanying', 'bowl', 'of', 'yogurt', 'mixed', 'with', 'the', 'chopped', 'parsley', '.']
# ['Place', 'all', 'the', 'ijeh', 'ingredients', 'in', 'a', 'medium-size', 'bowl', 'and', 'mix', 'well', '.']
# ['Reduce', 'the', 'oven', 'temperature', 'to', '350°F', '.']
# ['Preheat', 'oven', 'to', '350°F', '(', '180°C', ')']
# ['In', 'a', 'large', 'bowl', ',', 'whisk', 'together', 'flour', ',', 'cinnamon', ',', 'baking', 'powder', ',', 'baking', 'soda', 'and', 'salt', '.']
# ['In', 'a', 'medium', 'bowl', ',', 'whisk', 'together', 'eggs', ',', 'agave', 'nectar', 'and', 'butter', 'until', 'well', 'blended', '.']
# ['Add', 'the', 'egg', 'mixture', 'to', 'the', 'flour', 'mixture', 'and', 'stir', 'until', 'just', 'blended', '.', 'Gently', 'fold', 'in', 'zucchini', 'and', 'pecans', '.']
# ['Divide', 'batter', 'equally', 'among', 'prepared', 'muffin', 'cups', '.']
# ['First', 'make', 'the', 'sauce', '.', 'Meanwhile', ',', 'Preheat', 'an', 'oven', 'to', '375', 'degrees', 'F', '.']
# ['Put', 'the', 'strips', 'in', 'a', 'bowl', '.', 'Add', '2', 'teaspoons', 'of', 'the', 'salt', 'and', 'mix', 'well', '.']
# ['Set', 'aside', 'for', '15', 'minutes', '.', 'Drain', 'and', 'pat', 'as', 'dry', 'as', 'possible', 'in', 'a', 'dish', 'towel', '.']
# ['Add', 'the', 'shao', 'hsing', 'by', 'pouring', 'it', 'around', 'the', 'edges', 'of', 'the', 'wok', 'and', 'letting', 'it', 'slither', 'down', 'toward', 'the', 'zucchini', '.']
# ['Stir', 'again', 'and', 'serve', 'immediately', '.']
# ['Light', 'a', 'charcoal', 'fire', 'or', 'preheat', 'your', 'gas', 'grill', 'on', 'high', '.', 'Oil', 'the', 'grill', '’', 's', 'cooking', 'surface', '.']
# ['Testing', 'the', 'cheese', '(', 'the', 'day', 'before', 'you', 'make', 'the', 'gnocchi', ')', ':']
# ['Making', 'the', 'batter', ':']
# ['Forming', 'and', 'testing', 'a', 'sample', 'gnocchi', ':']
# ['Make', 'a', 'bed', 'of', 'flour', 'about', '½', 'inch', 'deep', 'in', 'a', 'shallow', 'baking', 'dish', 'or', 'on', 'a', 'sheet', 'pan', '.']
# ['Taste', 'the', 'sample', 'for', 'salt', ',', 'and', 'adjust', 'the', 'batter', 'if', 'needed', '.']
# ['Forming', 'the', 'remaining', 'gnocchi', ':']
# ['Cooking', 'the', 'gnocchi', ':']
# ['Place', 'the', '8', 'tablespoons', 'of', 'butter', 'and', 'the', '2', 'teaspoons', 'of', 'water', 'in', 'a', '12-inch', 'skillet', ';', 'set', 'aside', '.']
# ['Variation', ':', 'Spinach', 'and', 'Ricotta', 'Gnocchi']
# ['Bring', '3', 'cups', 'water', 'to', 'a', 'boil', '.', 'Add', 'a', 'pinch', 'of', 'salt', 'and', 'the', 'spinach', '.']
# 26620  recipes filtered out
# Recipe step pairs:  469

# %%
total_loss = 0
outputs = []

for t in test_data_steps:
    output, loss, attention = evaluate_with_given_input(t)
    total_loss += loss
    outputs.append(output)
    
print("Average loss for test set: ", total_loss/len(test_data_steps))
# Out:
# Average loss for test set:  17.362350101664216

# %%
random_evaluate(test_data_steps)
# Out:
# Instruction step <SOS> Toast the waffles to desired crispness . <EOS>
# Next step <SOS> Spread the peanut butter on one side of each waffle . <EOS>
# Generated instructions <SOS> Place the cooked potatoes on top of the apple mixture and the top of the pastry . <EOS>
# Loss:  8.781548720139723
#
# Instruction step <SOS> Add beer ; allow <LN> to continue to ferment for 24 hours more . <EOS>
# Next step <SOS> Strain liquid ; discard fruit ; add sugar substitute . <EOS>
# Generated instructions <SOS> Stir in the cream cheese , <EOS>
# Loss:  6.810345967610677
#
# Instruction step <SOS> Place the mango , juice , and yogurt in a blender , and blend until well combined . <EOS>
# Next step <SOS> Pour into individual glasses and serve with a straw . <EOS>
# Generated instructions <SOS> Add the cream and mix well . <EOS>
# Loss:  9.21328862508138
#
# Instruction step <SOS> Combine the mustard and vinegar in a bowl and stir to mix . Allow the mixture to sit for 15 minutes . <EOS>
# Next step <SOS> Place all of the ingredients in a blender or food processor and process until smooth . <EOS>
# Generated instructions <SOS> Pour the mixture into a large bowl and stir in the sugar and the salt and pepper . <EOS>
# Loss:  9.218621148003471
#
# Instruction step <SOS> Add the melted butter and lemon zest . <EOS>
# Next step <SOS> Pour the glaze over the potatoes and bake for 15 to 20 minutes , until glazed and heated through . <EOS>
# Generated instructions <SOS> Add the flour and salt and stir until well combined . <EOS>
# Loss:  9.250845475630326
#
# Instruction step <SOS> 3 sprigs thyme or marjoram <EOS>
# Next step <SOS> 5 peppercorns <EOS>
# Generated instructions <SOS> Place in large bowl and stir in the microwave until the onion is soft . about 5 minutes . <EOS>
# Loss:  51.26087188720703
#
# Instruction step <SOS> Cover tightly and cook until the sugar has melted and the berries begin to give off their juice . <EOS>
# Next step <SOS> Remove from the heat and serve immediately with the birds . <EOS>
# Generated instructions <SOS> Add the flour and salt and stir until the sugar is dissolved . <EOS>
# Loss:  8.627655616173378
#
# Instruction step <SOS> Thread 1 fig half , 1 prosciutto strip , and 1 arugula leaf onto a wooden skewer . Season with pepper . <EOS>
# Next step <SOS> Scatter with Parmesan shavings and arugula leaves and serve . <EOS>
# Generated instructions <SOS> Cook in stirring occasionally , until browned , about 5 minutes . <EOS>
# Loss:  10.132151285807291
#
# Instruction step <SOS> Blend in the melted butter , eggs , and buttermilk . <EOS>
# Next step <SOS> Mix until the flour is dampened . Add the grated lemon peel and the vanilla extract . <EOS>
# Generated instructions <SOS> Add the flour mixture and mix well . <EOS>
# Loss:  8.910189176860609
#
# Instruction step <SOS> 1½ cups Basic Chicken Stock <EOS>
# Next step <SOS> ½ cup white wine <EOS>
# Generated instructions <SOS> In a large bowl , mix together the flour , salt , and sugar . Stir in the eggs , and mix well . <EOS>
# Loss:  42.733011881510414

# %%
evaluate_with_given_input(test_data_steps[205])
# Out:
# ('<SOS> Place the bread cubes in a large bowl , and mix in the bread crumbs . <EOS>',
#  11.055631510416667,
#  tensor([[3.0162e-15, 1.5212e-12, 1.2896e-11,  ..., 6.3481e-11, 8.6996e-11,
#           7.9750e-11],
#          [1.0734e-16, 1.9691e-10, 1.8610e-12,  ..., 2.5933e-12, 1.3124e-12,
#           1.7030e-12],
#          [1.0000e+00, 1.3360e-08, 3.7519e-08,  ..., 6.0348e-09, 2.7222e-09,
#           5.3871e-09],
#          ...,
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#           0.0000e+00]]))

# %%
from nltk.translate import bleu_score, meteor_score
from nltk.metrics import scores
from rouge_score import rouge_scorer


avg_prec = 0
avg_recall = 0
avg_fscore = 0
avg_bleu = 0
#avg_rouge = []
avg_meteor = 0
avg_len = 0

N = len(test_data_steps)
results = []
targets = []
#scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=False)


for i, t in enumerate(test_data_steps):
    input_step = [str(s) for s in t[0].flatten().tolist()]
    target = [str(s) for s in t[1].flatten().tolist()]
    targets.append(target)
    result = outputs[i]
    #print(input_step)
    #print(target)
    #print(result)
    result_vec = [str(r) for r in prepare_input_instruction_eval(result).flatten().tolist()]
    results.append(result_vec)
    avg_len += len(result_vec)
    # sanity check
    #prep = idx_to_words(result_vec, idx2word)
    #print(result_vec)
    precision = scores.precision(set(result_vec), set(target))
    avg_prec += precision
    recall = scores.recall(set(result_vec), set(target))
    avg_recall += recall
    f_score = scores.f_measure(set(result_vec), set(target))
    avg_fscore += f_score
    bleu = bleu_score.sentence_bleu([target], result)
    avg_bleu += bleu
    rouge = scorer.score(" ".join(target), " ".join(result))
    #print(rouge)
    #avg_rouge.append(rouge['rougeL']['precision']
    meteor = meteor_score.single_meteor_score(" ".join(target), " ".join(result))
    avg_meteor += meteor

print("Average precision: ", avg_prec/N)
print("Average recall: ", avg_recall/N)
#print("F1-measure: ", avg_fscore/N)

print("Average BLEU: ", avg_bleu/N)
print("Average METEOR: ", avg_meteor/N)
#print("Average ROUGE-L: ", avg_bleu/N)
print("Average step length: ", avg_len/N)
# Out:
# Average precision:  0.38914280386514505
# Average recall:  0.3112145435106619
# Average BLEU:  8.878445206863794e-234
# Average METEOR:  0.0017409686016970072
# Average step length:  23.215351812366738

# %%
# Out:
# 145.95962090650045
